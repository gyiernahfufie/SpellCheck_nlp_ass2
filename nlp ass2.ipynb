# %%
#only run when added new files into corpus 
import glob

read_files = glob.glob("*.txt")

with open("merged_corpus.txt", "wb") as outfile:
    for f in read_files:
        with open(f, "rb") as infile:
            outfile.write(infile.read())

# %%
pwd
# Out:
# 'C:\\Users\\User\\Downloads\\NLP ASS 2\\NLP_Spellchecker_App-master (1)'

# %%
import os

# %%
path = "C:\\Users\\User\\Downloads\\NLP ASS 2\\NLP_Spellchecker_App-master (1)\\corpus"
dirs = os.chdir(path)

# %%
import re
from collections import Counter
import numpy as np
import pandas as pd
import math
import random
import numpy as np
import pandas as pd
import nltk
import string 
import matplotlib
matplotlib.use('Agg')

# %%
with open("merged_corpus.txt", "r", encoding = 'ISO-8859-1') as f: 
    data = f.read()

# %%
#514-8 = proj gutenberg 
#medical vocab = https://github.com/socd06/medical-nlp
#medical articles = https://www.kaggle.com/trikialaaa/2k-clean-medical-articles-medicalnewstoday/tasks
#merged corpus = 514-8 + medical articles

# %%
#Preprocess file    
data = re.sub(r'[^A-Za-z\.\?!\']+', ' ', data) #remove special character
data = re.sub(r'\b(?:[A-Z]{3,}\b|(?:[A-Za-z]\.){2,})\s*', ' ',data)# removes 3 or more capital letters e.g. XYZ or X.Y.Z. 
sentences = re.split(r'[\.\?!]+[ \n]+', data) #split data into sentences
sentences = [s.strip() for s in sentences] #Remove leading & trailing spaces
sentences = [s for s in sentences if len(s) > 0] #Remove whitespace

# %%
tokenized_sentences=[]
# this is the new tokenisation for sentences. This will keep all words including "shouldn't". Removes numbers and non words like e.g. and etc. 
for sentence in sentences: 
        non_words = ['etc'] 
        # Convert to lowercase letters
        sentence = sentence.lower() 
        
        # Convert into a list of words
        tokenized = re.findall("[\w']+", sentence) #tokenises words. keeps numbers keeps shouldn't but has e and g in list from e.g. 
        
        # Remove random letters leftover from tokenising. 
        one_word = list(string.ascii_lowercase[0:26])
        one_word.remove('a')
        one_word.remove('i')
        
        for i in list(tokenized):
            if i in one_word:
                tokenized.remove(i)
                
        # remove non_words i.e. 'etc'
        for word in list(tokenized): 
                if word in non_words: 
                    tokenized.remove(word) 
        # append the list of tokenized_sentences to the list of lists
        tokenized_sentences.append(tokenized)

# %%
def count_words(tokenized_sentences):
    """
    Count the number of each individual word in every sentences
    """
    word_counts = {}
    for sentence in tokenized_sentences: # complete this line
        word_counts
        # Go through each token in the sentence
        for token in sentence: # complete this line

            # If the token is not in the dictionary yet, set the count to 1
            if not token in word_counts: # complete this line
                word_counts[token] = 1
            
            # If the token is already in the dictionary, increment the count by 1
            else:
                word_counts[token] += 1

    
    return word_counts

def get_nplus_words(tokenized_sentences, n):
    """
    Find words in corpus with nplus frequency
    """
    nplus_vocab = []
    
    word_counts = count_words(tokenized_sentences)

    for word, cnt in word_counts.items():
        if cnt >= n:
            nplus_vocab.append(word)
    
    return  nplus_vocab

def replace_words_below_n_by_unk(tokenized_sentences, n=2):
    """
    Process training data to replace words with frequency less than n by UNK
    """
    vocabulary = set(get_nplus_words(tokenized_sentences, n))
    
    processed_tokenized_sentences = []
    
    for sentence in tokenized_sentences:
        temp_sentence = []
        
        for token in sentence: 
            if token in vocabulary: # complete this line
                temp_sentence.append(token)
            else:
                temp_sentence.append("<unk>")
        
        processed_tokenized_sentences.append(temp_sentence)
        
    return processed_tokenized_sentences

# %%
path = "C:\\Users\\User\\Downloads\\NLP ASS 2\\NLP_Spellchecker_App-master (1)"
dirs = os.chdir(path)

# %%
with open("medical_vocab.txt", "r", encoding = 'ISO-8859-1') as f: 
    medical_vocab = f.read()

# %%
medical_vocab = re.sub(r'[^A-Za-z\.\?!\']+', ' ', medical_vocab) #remove special character
medical_vocab = re.sub(r'\b(?:[A-Z]{3,}\b|(?:[A-Za-z]\.){2,})\s*', ' ',medical_vocab)# removes 3 or more capital letters e.g. XYZ or X.Y.Z.

# %%
from nltk.tokenize import word_tokenize
medical_vocab = word_tokenize(medical_vocab)

# %%
# Get Vocabulary
vocabulary = list(set(get_nplus_words(tokenized_sentences, 2))) #words with more than 2 frequency
vocabulary = vocabulary + medical_vocab #append medical vocab to gutenberg vocab
vocabulary = vocabulary+['<s>']+['<e>']
# Replace less frequent word by <UNK>
processed_sentences =replace_words_below_n_by_unk(tokenized_sentences, 2)

# %%
def n_grams_dict(tokenized_sentences, n, start_token='<s>', end_token = '<e>'):
    """
    Return all n_grams with count
    """  
    n_grams = {}

    for sentence in tokenized_sentences: # complete this line
        
        # add start and end token
        sentence = n * [start_token] + sentence + [end_token]
        # convert to tuple
        sentence = tuple(sentence)

        for i in range(len(sentence)-n+1): 

            n_gram = sentence[i:i+n]
            
            if n_gram in n_grams:
                n_grams[n_gram] += 1
            else:
                n_grams[n_gram] = 1
    
            ### END CODE HERE ###
    return n_grams

# %%
# Get the unigram and bigram
unigram_counts = n_grams_dict(processed_sentences, 1)
bigram_counts = n_grams_dict(processed_sentences, 2)

# %%
import numpy as np
def delete_letter(word, verbose=True):
    '''return list of word with deleted letter
    '''
    
    delete_l = []
    split_l = []
    
    split_l = [(word[:i], word[i:]) for i in range(len(word)+1)]
    delete_l = [L+R[1:] for L,R in split_l if R]

    if verbose: print(f"input word {word}, \ndelete_l = {delete_l}")

    return delete_l

def transpose_letter(word, verbose=False):
    '''
    return list of words with transposed letter
    ''' 
    
    transpose_l = []
    split_l = []

    split_l = [(word[:i], word[i:]) for i in range(len(word)+1)]
    transpose_l = [L + R[1] + R[0] + R[2:] for L,R in split_l if len(R)>1]
    
    if verbose: print(f"Input word = {word} \ntranspose_l = {transpose_l}") 

    return transpose_l

def subst_letter(word, verbose=False):
    '''
    return list of substitute letter
    ''' 
    
    letters = 'abcdefghijklmnopqrstuvwxyz'
    subst_l = []
    split_l = []

    split_l = [(word[:i], word[i:]) for i in range(len(word)+1)]
    subst_l = [L + l + R[1:] for L,R in split_l if R for l in letters]
    subst_set = set(subst_l)    
    subst_set.discard(word)

    # turn the set back into a list and sort it, for easier viewing
    subst_l = sorted(list(subst_set))
    
    if verbose: print(f"Input word = {word} \nsubst_l {subst_l}")   
    
    return subst_l

def ins_letter(word, verbose=False):
    '''
     return list of words with inserted letter
    ''' 
    letters = 'abcdefghijklmnopqrstuvwxyz'
    ins_l = []
    split_l = []
    

    split_l = [(word[:i], word[i:]) for i in range(len(word)+1)]
    ins_l = [L + l + R for L,R in split_l for l in letters]
    
    if verbose: print(f"Input word {word} \nins_l = {ins_l}")
    
    return ins_l

def edit_one_letter(word):
    """
    return a set of real/non word which is within edit distance of one 
    """
    edit_one_set = set(delete_letter(word) + transpose_letter(word) + subst_letter(word) + ins_letter(word))
    
    return edit_one_set

def edit_two_letters(word):
    '''
    return a set of real/non word which is within edit distance of two
    '''
    
    edit_one = edit_one_letter(word)
    edit_two_set = set()
    for w in edit_one:
        edit_two = edit_one_letter(w)
        edit_two_set = edit_two_set.union(edit_two_set, edit_two)
   
    return edit_two_set

def min_edit_distance(source, target, ins_cost = 1, del_cost = 1, rep_cost = 1, trp_cost= 1):

    # use deletion and insert cost as  1
    m = len(source) 
    n = len(target) 
    #initialize cost matrix with zeros and dimensions (m+1,n+1) 
    D = np.zeros((m+1, n+1), dtype=int) 
    

   # Fill in column 0, from row 1 to row m, both inclusive
    for row in range(1,m+1): 
        D[row,0] = D[row-1, 0] + del_cost
        
    # Fill in row 0, for all columns from 1 to n, both inclusive
    for col in range(1,n+1): 
        D[0,col] = D[0, col-1] + ins_cost
                
    # Loop through row 1 to row m, both inclusive
    for row in range(1,m+1): 
        
        # Loop through column 1 to column n, both inclusive
        for col in range(1,n+1):
            
            # Intialize r_cost to the 'replace' cost that is passed into this function
            r_cost = rep_cost
            
            # Check to see if source character at the previous row
            # matches the target character at the previous column, 
            if source[row-1] == target[col-1]:
                # Update the replacement cost to 0 if source and target are the same
                r_cost = 0
              
            # Update the cost at row, col based on previous entries in the cost matrix
            D[row,col] = min (D[row, col-1] + ins_cost, D[row-1, col] + del_cost, D[row-1, col-1] + r_cost)
            # transposition  
            if row>1 and col>1 and source[row-1]==target[col-2] and source[row-2] == target[col-1]:
                D[row,col] = min (D[row,col], D[row-2,col-2] + trp_cost) 
    # Set the minimum edit distance with the cost found at row m, column n
    min_distance = D[m,n]
    
    
    return D, min_distance

# %%
import ast
f=open('addconfusion.data', 'r')
data=f.read()
f.close
addmatrix=ast.literal_eval(data)
f=open('subconfusion.data', 'r')
data=f.read()
f.close
submatrix=ast.literal_eval(data)
f=open('revconfusion.data', 'r')
data=f.read()
f.close
revmatrix=ast.literal_eval(data)
f=open('delconfusion.data', 'r')
data=f.read()
f.close
delmatrix=ast.literal_eval(data)

def editType(candidate, word):
        "Method to calculate edit type for single edit errors."
        edit=[False]*4
        correct=""
        error=""
        x=''
        w=''
        for i in range(min([len(word),len(candidate)])-1):
            if candidate[0:i+1] != word[0:i+1]:
                if candidate[i:] == word[i-1:]:
                    edit[1]=True
                    correct = candidate[i-1]
                    error = ''
                    x = candidate[i-2]
                    w = candidate[i-2]+candidate[i-1]
                    break
                elif candidate[i:] == word[i+1:]:
                    
                    correct = ''
                    error = word[i]
                    if i == 0:
                        w = '#'
                        x = '#'+error
                    else:
                        w=word[i-1]
                        x=word[i-1]+error
                    edit[0]=True
                    break
                if candidate[i+1:] == word[i+1:]:
                    edit[2]=True
                    correct = candidate[i]
                    error = word[i]
                    x = error
                    w = correct
                    break
                if candidate[i] == word[i+1] and candidate[i+2:]==word[i+2:]:
                    edit[3]=True
                    correct = candidate[i]+candidate[i+1]
                    error = word[i]+word[i+1]
                    x=error
                    w=correct
                    break
        candidate=candidate[::-1]
        word=word[::-1]
        for i in range(min([len(word),len(candidate)])-1):
            if candidate[0:i+1] != word[0:i+1]:
                if candidate[i:] == word[i-1:]:
                    edit[1]=True
                    correct = candidate[i-1]
                    error = ''
                    x = candidate[i-2]
                    w = candidate[i-2]+candidate[i-1]
                    break
                elif candidate[i:] == word[i+1:]:
                    
                    correct = ''
                    error = word[i]
                    if i == 0:
                        w = '#'
                        x = '#'+error
                    else:
                        w=word[i-1]
                        x=word[i-1]+error
                    edit[0]=True
                    break
                if candidate[i+1:] == word[i+1:]:
                    edit[2]=True
                    correct = candidate[i]
                    error = word[i]
                    x = error
                    w = correct
                    break
                if candidate[i] == word[i+1] and candidate[i+2:]==word[i+2:]:
                    edit[3]=True
                    correct = candidate[i]+candidate[i+1]
                    error = word[i]+word[i+1]
                    x=error
                    w=correct
                    break
        if word == candidate:
            return "None", '', '', '', ''
        if edit[1]:
            return "Deletion", correct, error, x, w
        elif edit[0]:
            return "Insertion", correct, error, x, w
        elif edit[2]:
            return "Substitution", correct, error, x, w
        elif edit[3]:
            return "Reversal", correct, error, x, w
        
def channelModel(x,y, edit,corpus):
        """Method to calculate channel model probability for errors."""
        
        if edit == 'add':
            if x == '#':
                return addmatrix[x+y]/corpus.count(' '+y)
            else:
                return addmatrix[x+y]/corpus.count(x)
        if edit == 'sub':
            return submatrix[(x+y)[0:2]]/corpus.count(y)
        if edit == 'rev':
            return revmatrix[x+y]/corpus.count(x+y)
        if edit == 'del':
            return delmatrix[x+y]/corpus.count(x+y)

# %%
def get_probability(previous_n_words, word, 
                         previous_n_gram_dict, n_gram_dict, vocabulary_size, k=1.0):
    """
    Return N-gram probability given the pair of current word and previous_n_words
    """
    assert type(previous_n_words) == list
    # convert list to tuple to use it as a dictionary key
    previous_n_words = tuple(previous_n_words,)
    
    previous_n_words_count = previous_n_gram_dict[previous_n_words] if previous_n_words in previous_n_gram_dict else 0

    # k-smoothing
    denominator = previous_n_words_count + k*vocabulary_size

    # Define n plus 1 gram as the previous n-gram plus the current word as a tuple
    n_gram = previous_n_words + (word,)

    n_gram_count = n_gram_dict[n_gram] if n_gram in n_gram_dict else 0
   
    # smoothing
    numerator = n_gram_count + 1

    probability = numerator/denominator
    
    
    return probability

# %%
def get_corrections(previous_n_words_i, word, vocab, n=2, verbose = False):
    '''
    Get n candidates with individual probability
    '''
    assert type(previous_n_words_i) == list
    corpus = ' '.join(vocabulary)
    suggestions = []
    n_best = []
    ### Convert to UNK if word not in vocab
    previous_n_words = []
    for w in previous_n_words_i:
        if w not in vocabulary:
            previous_n_words.append('<unk>')
        else:
            previous_n_words.append(w)
            
    ##Suggestions include input word only if the input word in vocab
    if word in vocab:    
        suggestions = [word] + list(edit_one_letter(word).intersection(vocabulary)) or list(edit_two_letters(word).intersection(vocabulary)) 
    else:
        suggestions = list(edit_one_letter(word).intersection(vocabulary)) or list(edit_two_letters(word).intersection(vocabulary)) 
        
    words_prob = {}
    for w in suggestions: 
        # To make sure all suggestions is within edit distance of 2
        _, min_edits = min_edit_distance(' '.join(word),w)
        if not word in vocab: ##use error model only when it is non word error
            if min_edits <= 2:
                edit = editType(w,' '.join(word))
                if edit:##Some word cannot find edit
                    if edit[0] == "Insertion":
                        error_prob = channelModel(edit[3][0],edit[3][1], 'add',corpus)
                    if edit[0] == 'Deletion':
                        error_prob = channelModel(edit[4][0], edit[4][1], 'del',corpus)
                    if edit[0] == 'Reversal':
                        error_prob = channelModel(edit[4][0], edit[4][1], 'rev',corpus)
                    if edit[0] == 'Substitution':
                        error_prob = channelModel(edit[3], edit[4], 'sub',corpus)
                else:
                    error_prob = 1
            else:
                error_prob = 1
        else:
            error_prob = 1
        language_prob = get_probability(previous_n_words, w, 
                        unigram_counts, bigram_counts, len(vocabulary), k=1.0)
            
        words_prob[w] = language_prob * error_prob
        
    n_best = Counter(words_prob).most_common(n)
    
    if verbose: print("entered word = ", word, "\nsuggestions = ", suggestions)

    return n_best

# %%
#GUI Creations

# %%
# GUI CREATION THROUGH PYTHON'S TKINTER LIBRARY
from tkinter import *

# creates a base GUI window
root = Tk() 

# creating fixed geometry of the tkinter window with dimensions 700x900
root.geometry("705x780") 
root.configure(background = "gray76")

root.title("NLP Spell Checker") # Adding a title to the GUI window.
Label(root, text = "NLP Assignment 2", fg = "navy", bg = "gray", font = "Arial 11 bold italic", height = 3, width = 200).pack()

# %%
# function to retrieve the sentence typed by a user & pass the input through get_corrections() to check spellings
tokenized_sentence = []
non_real_word = []

clicked=StringVar()

# %%
def getInput():
    global tokenized_sentence
    # Preprocess the original text input to get clean input
    sentenceValues = entredSentence.get('1.0', '50.0')
    sentenceValues = sentenceValues.lower()
    outputSentence.delete(0.0, 'end')
    outputSentence.insert(END, sentenceValues)  
    
    # tokenize the sentence and save the values to tokenizedWords variable
    tokenized_sentence = nltk.word_tokenize(sentenceValues)
    tokenized_sentence = ['<s>']+ tokenized_sentence
    
    not_in_corpus=[]
    real_word_error=[]
    for word in tokenized_sentence:
        if word not in vocabulary:
            not_in_corpus.append(word)  # Saving non real word to not_in_corpus list.

    for word in tokenized_sentence[1:]:
        if word in vocabulary: 
            index=tokenized_sentence.index(word)
            candidate_words = get_corrections([tokenized_sentence[index-1]], word, vocabulary, n=1, verbose=False)
            if candidate_words[0][0] != word :
                real_word_error.append(word) # saving a real & existing word to real_word_error
    print(real_word_error)            
    print("Suitable candidate words are:")
    
    # Checking for non_word errors from the input sentence typed by a user
    options=[]
    for word in not_in_corpus:
        
        offset = '+%dc' % len(word) # +5c (5 chars)
    
        # search word from first char (1.0) to the end of text (END)
        pos_start = entredSentence.search(word, '1.0', END)
        
        # check if the word has been found
        while pos_start:
        
            # create end position by adding (as string "+5c") number of chars in searched word 
            pos_end = pos_start + offset
        
            # add tag
            entredSentence.tag_add('red_tag', pos_start, pos_end)
        
            # search again from pos_end to the end of text (END)
            pos_start = entredSentence.search(word, pos_end, END)
        
        options.append(word)   
    
    # checking for real word error from the input sentence by a user
    for word in real_word_error:
        offset = '+%dc' % len(word) # +5c (5 chars)
    
        # search word from first char (1.0) to the end of text (END)
        pos_start = entredSentence.search(word, '1.0', END)
        
        # check if the word has been found
        while pos_start:
        
            # create end position by adding (as string "+5c") number of chars in searched word 
            pos_end = pos_start + offset
        
            # add tag
            entredSentence.tag_add('blue_tag', pos_start, pos_end)
        
            # search again from pos_end to the end of text (END)
            pos_start = entredSentence.search(word, pos_end, END)
        
        options.append(word)   
    
    # Creating a drop down menu to display the misspelled words.
    # From this drop down list, a user selects the misspelled word that they need suggestions for.
    drop = OptionMenu(root,clicked,*options)
    drop.configure(font=("Arial", 10))
    drop.pack()
    drop.place(x=305, y = 350)

# %%
# Function to display a list of the suggested words
def showSuggestions():
    suggestedWords.delete(0, END)
    options=[]
    word_to_replace = clicked.get()
    index=tokenized_sentence.index(word_to_replace)
    
    candidate_words = get_corrections([tokenized_sentence[index-1]], word_to_replace, vocabulary, n=3, verbose=False)
    print(candidate_words)
    for i in range(len(candidate_words)):
        suggestedWords.insert(END,candidate_words[i][0])

# %%
# Function to replace a misspelled word with the correct word from a list of suggested words            
def replace_word():
    word_to_replace = clicked.get()
    selected_word=suggestedWords.get(ANCHOR)
    offset = '+%dc' % len(word_to_replace) # +5c (5 chars)
    idx = '1.0'
    #searches for desried string from index 1  
    idx = outputSentence.search(word_to_replace, idx, nocase = 1,  
                            stopindex = END) 
    # last index sum of current index and  
    # length of text  
    lastidx = '% s+% dc' % (idx, len(word_to_replace)) 
  
    outputSentence.delete(idx, lastidx) 
    outputSentence.insert(idx, selected_word) 
  
    lastidx = '% s+% dc' % (idx, len(selected_word))

# %%
# Input widget for sentence to be entered by user
Label(text="Enter sentence here (Max Words: 500)", font="Arial 11 bold").place(x=15, y=80)
entredSentence = Text(root, height = 10, width = 60)
entredSentence.configure(font=("Arial", 11))
entredSentence.place(x=15, y=110)
submit_btn = Button(root, height=1, width=10, text="Submit", command=getInput).place(x=585, y=110)
entredSentence.tag_config("red_tag", foreground="red", underline=1)
entredSentence.tag_config("blue_tag", foreground="blue", underline=1)

# Creating a suggestions widget for the suggested words to correct the mispelled word
Label(text="List of suggested words to replace misspelled word:", font = "Arial 11 bold").place(x=15, y=320)
suggestedWords = Listbox(root, height = 10, width = 30)
suggestedWords.configure(font=("Arial", 11))
#suggestedWords.config(state = "disabled")
suggestedWords.place(x=15, y = 350)
sugg_btn = Button(root, text="Show suggestions", command=showSuggestions).place(x=305, y=380)
replace_btn = Button(root, text="Replace Word", command=replace_word).place(x=305, y=410)

# Output widget for the sentence entered and open for correcting mispelled words
Label(text="Corrected Input Sentence by User:", font = "Arial 11 bold").place(x=15, y=560)
outputSentence = Text(root, height = 10, width = 60, wrap=WORD)
outputSentence.configure(font=("Arial", 11))
#outputSentence.config(state = "disabled")
outputSentence.place(x=15, y=590)

# Activating the GUI
root.mainloop()
# Out:
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word i,
# delete_l = ['']
# input word am,
# delete_l = ['m', 'a']
# input word afraid,
# delete_l = ['fraid', 'araid', 'afaid', 'afrid', 'afrad', 'afrai']
# input word that,
# delete_l = ['hat', 'tat', 'tht', 'tha']
# input word she,
# delete_l = ['he', 'se', 'sh']
# input word only,
# delete_l = ['nly', 'oly', 'ony', 'onl']
# input word has,
# delete_l = ['as', 'hs', 'ha']
# input word few,
# delete_l = ['ew', 'fw', 'fe']
# input word more,
# delete_l = ['ore', 'mre', 'moe', 'mor']
# input word months,
# delete_l = ['onths', 'mnths', 'moths', 'monhs', 'monts', 'month']
# input word to,
# delete_l = ['o', 't']
# input word live,
# delete_l = ['ive', 'lve', 'lie', 'liv']
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word system,
# delete_l = ['ystem', 'sstem', 'sytem', 'sysem', 'systm', 'syste']
# input word failure,
# delete_l = ['ailure', 'filure', 'falure', 'faiure', 'failre', 'failue', 'failur']
# input word you,
# delete_l = ['ou', 'yu', 'yo']
# input word should,
# delete_l = ['hould', 'sould', 'shuld', 'shold', 'shoud', 'shoul']
# input word be,
# delete_l = ['e', 'b']
# input word mentally,
# delete_l = ['entally', 'mntally', 'metally', 'menally', 'mentlly', 'mentaly', 'mentaly', 'mentall']
# input word prepared,
# delete_l = ['repared', 'pepared', 'prpared', 'preared', 'prepred', 'prepaed', 'prepard', 'prepare']
# input word she,
# delete_l = ['he', 'se', 'sh']
# input word will,
# delete_l = ['ill', 'wll', 'wil', 'wil']
# input word be,
# delete_l = ['e', 'b']
# input word unconscious,
# delete_l = ['nconscious', 'uconscious', 'unonscious', 'uncnscious', 'uncoscious', 'unconcious', 'unconsious', 'unconscous', 'unconscius', 'unconscios', 'unconsciou']
# input word for,
# delete_l = ['or', 'fr', 'fo']
# input word the,
# delete_l = ['he', 'te', 'th']
# input word next,
# delete_l = ['ext', 'nxt', 'net', 'nex']
# input word few,
# delete_l = ['ew', 'fw', 'fe']
# input word days,
# delete_l = ['ays', 'dys', 'das', 'day']
# input word this,
# delete_l = ['his', 'tis', 'ths', 'thi']
# input word may,
# delete_l = ['ay', 'my', 'ma']
# input word develop,
# delete_l = ['evelop', 'dvelop', 'deelop', 'devlop', 'deveop', 'develp', 'develo']
# input word into,
# delete_l = ['nto', 'ito', 'ino', 'int']
# input word long,
# delete_l = ['ong', 'lng', 'log', 'lon']
# input word cancer,
# delete_l = ['ancer', 'cncer', 'cacer', 'caner', 'cancr', 'cance']
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word the,
# delete_l = ['he', 'te', 'th']
# input word prolonged,
# delete_l = ['rolonged', 'polonged', 'prlonged', 'proonged', 'prolnged', 'prologed', 'proloned', 'prolongd', 'prolonge']
# input word effects,
# delete_l = ['ffects', 'efects', 'efects', 'effcts', 'effets', 'effecs', 'effect']
# input word of,
# delete_l = ['f', 'o']
# input word i,
# delete_l = ['']
# input word am,
# delete_l = ['m', 'a']
# input word sorry,
# delete_l = ['orry', 'srry', 'sory', 'sory', 'sorr']
# input word for,
# delete_l = ['or', 'fr', 'fo']
# input word your,
# delete_l = ['our', 'yur', 'yor', 'you']
# input word lost,
# delete_l = ['ost', 'lst', 'lot', 'los']
# ['due', 'she', 'has', 'live', 'due', 'she', 'due', 'your', 'lost']
# Suitable candidate words are:
# input word immue,
# delete_l = ['mmue', 'imue', 'imue', 'imme', 'immu']
# [('immune', 4.83744002673785e-05), ('immure', 8.795345503159727e-06)]
# input word bronchittiis,
# delete_l = ['ronchittiis', 'bonchittiis', 'brnchittiis', 'brochittiis', 'bronhittiis', 'broncittiis', 'bronchttiis', 'bronchitiis', 'bronchitiis', 'bronchittis', 'bronchittis', 'bronchittii']
# input word bronchittiis,
# delete_l = ['ronchittiis', 'bonchittiis', 'brnchittiis', 'brochittiis', 'bronhittiis', 'broncittiis', 'bronchttiis', 'bronchitiis', 'bronchitiis', 'bronchittis', 'bronchittis', 'bronchittii']
# input word bronchittiihs,
# delete_l = ['ronchittiihs', 'bonchittiihs', 'brnchittiihs', 'brochittiihs', 'bronhittiihs', 'broncittiihs', 'bronchttiihs', 'bronchitiihs', 'bronchitiihs', 'bronchittihs', 'bronchittihs', 'bronchittiis', 'bronchittiih']
# input word brtonchittiis,
# delete_l = ['rtonchittiis', 'btonchittiis', 'bronchittiis', 'brtnchittiis', 'brtochittiis', 'brtonhittiis', 'brtoncittiis', 'brtonchttiis', 'brtonchitiis', 'brtonchitiis', 'brtonchittis', 'brtonchittis', 'brtonchittii']
# input word brofchittiis,
# delete_l = ['rofchittiis', 'bofchittiis', 'brfchittiis', 'brochittiis', 'brofhittiis', 'brofcittiis', 'brofchttiis', 'brofchitiis', 'brofchitiis', 'brofchittis', 'brofchittis', 'brofchittii']
# input word bronchittiims,
# delete_l = ['ronchittiims', 'bonchittiims', 'brnchittiims', 'brochittiims', 'bronhittiims', 'broncittiims', 'bronchttiims', 'bronchitiims', 'bronchitiims', 'bronchittims', 'bronchittims', 'bronchittiis', 'bronchittiim']
# input word bronchittbis,
# delete_l = ['ronchittbis', 'bonchittbis', 'brnchittbis', 'brochittbis', 'bronhittbis', 'broncittbis', 'bronchttbis', 'bronchitbis', 'bronchitbis', 'bronchittis', 'bronchittbs', 'bronchittbi']
# input word bronchittimis,
# delete_l = ['ronchittimis', 'bonchittimis', 'brnchittimis', 'brochittimis', 'bronhittimis', 'broncittimis', 'bronchttimis', 'bronchitimis', 'bronchitimis', 'bronchittmis', 'bronchittiis', 'bronchittims', 'bronchittimi']
# input word bronchittiin,
# delete_l = ['ronchittiin', 'bonchittiin', 'brnchittiin', 'brochittiin', 'bronhittiin', 'broncittiin', 'bronchttiin', 'bronchitiin', 'bronchitiin', 'bronchittin', 'bronchittin', 'bronchittii']
# input word bronchiotiis,
# delete_l = ['ronchiotiis', 'bonchiotiis', 'brnchiotiis', 'brochiotiis', 'bronhiotiis', 'bronciotiis', 'bronchotiis', 'bronchitiis', 'bronchioiis', 'bronchiotis', 'bronchiotis', 'bronchiotii']
# input word bronchittias,
# delete_l = ['ronchittias', 'bonchittias', 'brnchittias', 'brochittias', 'bronhittias', 'broncittias', 'bronchttias', 'bronchitias', 'bronchitias', 'bronchittas', 'bronchittis', 'bronchittia']
# input word bjonchittiis,
# delete_l = ['jonchittiis', 'bonchittiis', 'bjnchittiis', 'bjochittiis', 'bjonhittiis', 'bjoncittiis', 'bjonchttiis', 'bjonchitiis', 'bjonchitiis', 'bjonchittis', 'bjonchittis', 'bjonchittii']
# input word bronchittics,
# delete_l = ['ronchittics', 'bonchittics', 'brnchittics', 'brochittics', 'bronhittics', 'broncittics', 'bronchttics', 'bronchitics', 'bronchitics', 'bronchittcs', 'bronchittis', 'bronchittic']
# input word bronchittyiis,
# delete_l = ['ronchittyiis', 'bonchittyiis', 'brnchittyiis', 'brochittyiis', 'bronhittyiis', 'broncittyiis', 'bronchttyiis', 'bronchityiis', 'bronchityiis', 'bronchittiis', 'bronchittyis', 'bronchittyis', 'bronchittyii']
# input word bponchittiis,
# delete_l = ['ponchittiis', 'bonchittiis', 'bpnchittiis', 'bpochittiis', 'bponhittiis', 'bponcittiis', 'bponchttiis', 'bponchitiis', 'bponchitiis', 'bponchittis', 'bponchittis', 'bponchittii']
# input word bronchhttiis,
# delete_l = ['ronchhttiis', 'bonchhttiis', 'brnchhttiis', 'brochhttiis', 'bronhhttiis', 'bronchttiis', 'bronchttiis', 'bronchhtiis', 'bronchhtiis', 'bronchhttis', 'bronchhttis', 'bronchhttii']
# input word bronchittiit,
# delete_l = ['ronchittiit', 'bonchittiit', 'brnchittiit', 'brochittiit', 'bronhittiit', 'broncittiit', 'bronchttiit', 'bronchitiit', 'bronchitiit', 'bronchittit', 'bronchittit', 'bronchittii']
# input word bronchpittiis,
# delete_l = ['ronchpittiis', 'bonchpittiis', 'brnchpittiis', 'brochpittiis', 'bronhpittiis', 'broncpittiis', 'bronchittiis', 'bronchpttiis', 'bronchpitiis', 'bronchpitiis', 'bronchpittis', 'bronchpittis', 'bronchpittii']
# input word bronchitriis,
# delete_l = ['ronchitriis', 'bonchitriis', 'brnchitriis', 'brochitriis', 'bronhitriis', 'broncitriis', 'bronchtriis', 'bronchiriis', 'bronchitiis', 'bronchitris', 'bronchitris', 'bronchitrii']
# input word broncyhittiis,
# delete_l = ['roncyhittiis', 'boncyhittiis', 'brncyhittiis', 'brocyhittiis', 'bronyhittiis', 'bronchittiis', 'broncyittiis', 'broncyhttiis', 'broncyhitiis', 'broncyhitiis', 'broncyhittis', 'broncyhittis', 'broncyhittii']
# input word bronchitticis,
# delete_l = ['ronchitticis', 'bonchitticis', 'brnchitticis', 'brochitticis', 'bronhitticis', 'broncitticis', 'bronchtticis', 'bronchiticis', 'bronchiticis', 'bronchittcis', 'bronchittiis', 'bronchittics', 'bronchittici']
# input word bronchitiis,
# delete_l = ['ronchitiis', 'bonchitiis', 'brnchitiis', 'brochitiis', 'bronhitiis', 'broncitiis', 'bronchtiis', 'bronchiiis', 'bronchitis', 'bronchitis', 'bronchitii']
# input word bronchitltiis,
# delete_l = ['ronchitltiis', 'bonchitltiis', 'brnchitltiis', 'brochitltiis', 'bronhitltiis', 'broncitltiis', 'bronchtltiis', 'bronchiltiis', 'bronchittiis', 'bronchitliis', 'bronchitltis', 'bronchitltis', 'bronchitltii']
# input word brzonchittiis,
# delete_l = ['rzonchittiis', 'bzonchittiis', 'bronchittiis', 'brznchittiis', 'brzochittiis', 'brzonhittiis', 'brzoncittiis', 'brzonchttiis', 'brzonchitiis', 'brzonchitiis', 'brzonchittis', 'brzonchittis', 'brzonchittii']
# input word bronchittiqis,
# delete_l = ['ronchittiqis', 'bonchittiqis', 'brnchittiqis', 'brochittiqis', 'bronhittiqis', 'broncittiqis', 'bronchttiqis', 'bronchitiqis', 'bronchitiqis', 'bronchittqis', 'bronchittiis', 'bronchittiqs', 'bronchittiqi']
# input word jbronchittiis,
# delete_l = ['bronchittiis', 'jronchittiis', 'jbonchittiis', 'jbrnchittiis', 'jbrochittiis', 'jbronhittiis', 'jbroncittiis', 'jbronchttiis', 'jbronchitiis', 'jbronchitiis', 'jbronchittis', 'jbronchittis', 'jbronchittii']
# input word brorchittiis,
# delete_l = ['rorchittiis', 'borchittiis', 'brrchittiis', 'brochittiis', 'brorhittiis', 'brorcittiis', 'brorchttiis', 'brorchitiis', 'brorchitiis', 'brorchittis', 'brorchittis', 'brorchittii']
# input word bronchitteiis,
# delete_l = ['ronchitteiis', 'bonchitteiis', 'brnchitteiis', 'brochitteiis', 'bronhitteiis', 'broncitteiis', 'bronchtteiis', 'bronchiteiis', 'bronchiteiis', 'bronchittiis', 'bronchitteis', 'bronchitteis', 'bronchitteii']
# input word bronahittiis,
# delete_l = ['ronahittiis', 'bonahittiis', 'brnahittiis', 'broahittiis', 'bronhittiis', 'bronaittiis', 'bronahttiis', 'bronahitiis', 'bronahitiis', 'bronahittis', 'bronahittis', 'bronahittii']
# input word brodchittiis,
# delete_l = ['rodchittiis', 'bodchittiis', 'brdchittiis', 'brochittiis', 'brodhittiis', 'brodcittiis', 'brodchttiis', 'brodchitiis', 'brodchitiis', 'brodchittis', 'brodchittis', 'brodchittii']
# input word broncehittiis,
# delete_l = ['roncehittiis', 'boncehittiis', 'brncehittiis', 'brocehittiis', 'bronehittiis', 'bronchittiis', 'bronceittiis', 'broncehttiis', 'broncehitiis', 'broncehitiis', 'broncehittis', 'broncehittis', 'broncehittii']
# input word bronchixttiis,
# delete_l = ['ronchixttiis', 'bonchixttiis', 'brnchixttiis', 'brochixttiis', 'bronhixttiis', 'broncixttiis', 'bronchxttiis', 'bronchittiis', 'bronchixtiis', 'bronchixtiis', 'bronchixttis', 'bronchixttis', 'bronchixttii']
# input word bronchittiss,
# delete_l = ['ronchittiss', 'bonchittiss', 'brnchittiss', 'brochittiss', 'bronhittiss', 'broncittiss', 'bronchttiss', 'bronchitiss', 'bronchitiss', 'bronchittss', 'bronchittis', 'bronchittis']
# input word bronbhittiis,
# delete_l = ['ronbhittiis', 'bonbhittiis', 'brnbhittiis', 'brobhittiis', 'bronhittiis', 'bronbittiis', 'bronbhttiis', 'bronbhitiis', 'bronbhitiis', 'bronbhittis', 'bronbhittis', 'bronbhittii']
# input word sbronchittiis,
# delete_l = ['bronchittiis', 'sronchittiis', 'sbonchittiis', 'sbrnchittiis', 'sbrochittiis', 'sbronhittiis', 'sbroncittiis', 'sbronchttiis', 'sbronchitiis', 'sbronchitiis', 'sbronchittis', 'sbronchittis', 'sbronchittii']
# input word bronchittiisd,
# delete_l = ['ronchittiisd', 'bonchittiisd', 'brnchittiisd', 'brochittiisd', 'bronhittiisd', 'broncittiisd', 'bronchttiisd', 'bronchitiisd', 'bronchitiisd', 'bronchittisd', 'bronchittisd', 'bronchittiid', 'bronchittiis']
# input word bronchittikis,
# delete_l = ['ronchittikis', 'bonchittikis', 'brnchittikis', 'brochittikis', 'bronhittikis', 'broncittikis', 'bronchttikis', 'bronchitikis', 'bronchitikis', 'bronchittkis', 'bronchittiis', 'bronchittiks', 'bronchittiki']
# input word broncfittiis,
# delete_l = ['roncfittiis', 'boncfittiis', 'brncfittiis', 'brocfittiis', 'bronfittiis', 'broncittiis', 'broncfttiis', 'broncfitiis', 'broncfitiis', 'broncfittis', 'broncfittis', 'broncfittii']
# input word broncyittiis,
# delete_l = ['roncyittiis', 'boncyittiis', 'brncyittiis', 'brocyittiis', 'bronyittiis', 'broncittiis', 'broncyttiis', 'broncyitiis', 'broncyitiis', 'broncyittis', 'broncyittis', 'broncyittii']
# input word broncheittiis,
# delete_l = ['roncheittiis', 'boncheittiis', 'brncheittiis', 'brocheittiis', 'bronheittiis', 'bronceittiis', 'bronchittiis', 'bronchettiis', 'broncheitiis', 'broncheitiis', 'broncheittis', 'broncheittis', 'broncheittii']
# input word bronrchittiis,
# delete_l = ['ronrchittiis', 'bonrchittiis', 'brnrchittiis', 'brorchittiis', 'bronchittiis', 'bronrhittiis', 'bronrcittiis', 'bronrchttiis', 'bronrchitiis', 'bronrchitiis', 'bronrchittis', 'bronrchittis', 'bronrchittii']
# input word brohchittiis,
# delete_l = ['rohchittiis', 'bohchittiis', 'brhchittiis', 'brochittiis', 'brohhittiis', 'brohcittiis', 'brohchttiis', 'brohchitiis', 'brohchitiis', 'brohchittis', 'brohchittis', 'brohchittii']
# input word bronchithtiis,
# delete_l = ['ronchithtiis', 'bonchithtiis', 'brnchithtiis', 'brochithtiis', 'bronhithtiis', 'broncithtiis', 'bronchthtiis', 'bronchihtiis', 'bronchittiis', 'bronchithiis', 'bronchithtis', 'bronchithtis', 'bronchithtii']
# input word bronchityiis,
# delete_l = ['ronchityiis', 'bonchityiis', 'brnchityiis', 'brochityiis', 'bronhityiis', 'broncityiis', 'bronchtyiis', 'bronchiyiis', 'bronchitiis', 'bronchityis', 'bronchityis', 'bronchityii']
# input word bronchittieis,
# delete_l = ['ronchittieis', 'bonchittieis', 'brnchittieis', 'brochittieis', 'bronhittieis', 'broncittieis', 'bronchttieis', 'bronchitieis', 'bronchitieis', 'bronchitteis', 'bronchittiis', 'bronchitties', 'bronchittiei']
# input word bronchittjiis,
# delete_l = ['ronchittjiis', 'bonchittjiis', 'brnchittjiis', 'brochittjiis', 'bronhittjiis', 'broncittjiis', 'bronchttjiis', 'bronchitjiis', 'bronchitjiis', 'bronchittiis', 'bronchittjis', 'bronchittjis', 'bronchittjii']
# input word bronchithiis,
# delete_l = ['ronchithiis', 'bonchithiis', 'brnchithiis', 'brochithiis', 'bronhithiis', 'broncithiis', 'bronchthiis', 'bronchihiis', 'bronchitiis', 'bronchithis', 'bronchithis', 'bronchithii']
# input word bronchittiio,
# delete_l = ['ronchittiio', 'bonchittiio', 'brnchittiio', 'brochittiio', 'bronhittiio', 'broncittiio', 'bronchttiio', 'bronchitiio', 'bronchitiio', 'bronchittio', 'bronchittio', 'bronchittii']
# input word brnchittiis,
# delete_l = ['rnchittiis', 'bnchittiis', 'brchittiis', 'brnhittiis', 'brncittiis', 'brnchttiis', 'brnchitiis', 'brnchitiis', 'brnchittis', 'brnchittis', 'brnchittii']
# input word bronchittiiv,
# delete_l = ['ronchittiiv', 'bonchittiiv', 'brnchittiiv', 'brochittiiv', 'bronhittiiv', 'broncittiiv', 'bronchttiiv', 'bronchitiiv', 'bronchitiiv', 'bronchittiv', 'bronchittiv', 'bronchittii']
# input word bruonchittiis,
# delete_l = ['ruonchittiis', 'buonchittiis', 'bronchittiis', 'brunchittiis', 'bruochittiis', 'bruonhittiis', 'bruoncittiis', 'bruonchttiis', 'bruonchitiis', 'bruonchitiis', 'bruonchittis', 'bruonchittis', 'bruonchittii']
# input word hronchittiis,
# delete_l = ['ronchittiis', 'honchittiis', 'hrnchittiis', 'hrochittiis', 'hronhittiis', 'hroncittiis', 'hronchttiis', 'hronchitiis', 'hronchitiis', 'hronchittis', 'hronchittis', 'hronchittii']
# input word bnronchittiis,
# delete_l = ['nronchittiis', 'bronchittiis', 'bnonchittiis', 'bnrnchittiis', 'bnrochittiis', 'bnronhittiis', 'bnroncittiis', 'bnronchttiis', 'bnronchitiis', 'bnronchitiis', 'bnronchittis', 'bnronchittis', 'bnronchittii']
# input word bronchittiia,
# delete_l = ['ronchittiia', 'bonchittiia', 'brnchittiia', 'brochittiia', 'bronhittiia', 'broncittiia', 'bronchttiia', 'bronchitiia', 'bronchitiia', 'bronchittia', 'bronchittia', 'bronchittii']
# input word bronchittiiks,
# delete_l = ['ronchittiiks', 'bonchittiiks', 'brnchittiiks', 'brochittiiks', 'bronhittiiks', 'broncittiiks', 'bronchttiiks', 'bronchitiiks', 'bronchitiiks', 'bronchittiks', 'bronchittiks', 'bronchittiis', 'bronchittiik']
# input word bronchitqiis,
# delete_l = ['ronchitqiis', 'bonchitqiis', 'brnchitqiis', 'brochitqiis', 'bronhitqiis', 'broncitqiis', 'bronchtqiis', 'bronchiqiis', 'bronchitiis', 'bronchitqis', 'bronchitqis', 'bronchitqii']
# input word brondchittiis,
# delete_l = ['rondchittiis', 'bondchittiis', 'brndchittiis', 'brodchittiis', 'bronchittiis', 'brondhittiis', 'brondcittiis', 'brondchttiis', 'brondchitiis', 'brondchitiis', 'brondchittis', 'brondchittis', 'brondchittii']
# input word lronchittiis,
# delete_l = ['ronchittiis', 'lonchittiis', 'lrnchittiis', 'lrochittiis', 'lronhittiis', 'lroncittiis', 'lronchttiis', 'lronchitiis', 'lronchitiis', 'lronchittis', 'lronchittis', 'lronchittii']
# input word broncbittiis,
# delete_l = ['roncbittiis', 'boncbittiis', 'brncbittiis', 'brocbittiis', 'bronbittiis', 'broncittiis', 'broncbttiis', 'broncbitiis', 'broncbitiis', 'broncbittis', 'broncbittis', 'broncbittii']
# input word bronchittilis,
# delete_l = ['ronchittilis', 'bonchittilis', 'brnchittilis', 'brochittilis', 'bronhittilis', 'broncittilis', 'bronchttilis', 'bronchitilis', 'bronchitilis', 'bronchittlis', 'bronchittiis', 'bronchittils', 'bronchittili']
# input word bronchittiis,
# delete_l = ['ronchittiis', 'bonchittiis', 'brnchittiis', 'brochittiis', 'bronhittiis', 'broncittiis', 'bronchttiis', 'bronchitiis', 'bronchitiis', 'bronchittis', 'bronchittis', 'bronchittii']
# input word bronchittiixs,
# delete_l = ['ronchittiixs', 'bonchittiixs', 'brnchittiixs', 'brochittiixs', 'bronhittiixs', 'broncittiixs', 'bronchttiixs', 'bronchitiixs', 'bronchitiixs', 'bronchittixs', 'bronchittixs', 'bronchittiis', 'bronchittiix']
# input word hbronchittiis,
# delete_l = ['bronchittiis', 'hronchittiis', 'hbonchittiis', 'hbrnchittiis', 'hbrochittiis', 'hbronhittiis', 'hbroncittiis', 'hbronchttiis', 'hbronchitiis', 'hbronchitiis', 'hbronchittis', 'hbronchittis', 'hbronchittii']
# input word blronchittiis,
# delete_l = ['lronchittiis', 'bronchittiis', 'blonchittiis', 'blrnchittiis', 'blrochittiis', 'blronhittiis', 'blroncittiis', 'blronchttiis', 'blronchitiis', 'blronchitiis', 'blronchittis', 'blronchittis', 'blronchittii']
# input word bronchittwis,
# delete_l = ['ronchittwis', 'bonchittwis', 'brnchittwis', 'brochittwis', 'bronhittwis', 'broncittwis', 'bronchttwis', 'bronchitwis', 'bronchitwis', 'bronchittis', 'bronchittws', 'bronchittwi']
# input word btonchittiis,
# delete_l = ['tonchittiis', 'bonchittiis', 'btnchittiis', 'btochittiis', 'btonhittiis', 'btoncittiis', 'btonchttiis', 'btonchitiis', 'btonchitiis', 'btonchittis', 'btonchittis', 'btonchittii']
# input word bronchettiis,
# delete_l = ['ronchettiis', 'bonchettiis', 'brnchettiis', 'brochettiis', 'bronhettiis', 'broncettiis', 'bronchttiis', 'bronchetiis', 'bronchetiis', 'bronchettis', 'bronchettis', 'bronchettii']
# input word bronchitthis,
# delete_l = ['ronchitthis', 'bonchitthis', 'brnchitthis', 'brochitthis', 'bronhitthis', 'broncitthis', 'bronchtthis', 'bronchithis', 'bronchithis', 'bronchittis', 'bronchitths', 'bronchitthi']
# input word bvonchittiis,
# delete_l = ['vonchittiis', 'bonchittiis', 'bvnchittiis', 'bvochittiis', 'bvonhittiis', 'bvoncittiis', 'bvonchttiis', 'bvonchitiis', 'bvonchitiis', 'bvonchittis', 'bvonchittis', 'bvonchittii']
# input word bronchihttiis,
# delete_l = ['ronchihttiis', 'bonchihttiis', 'brnchihttiis', 'brochihttiis', 'bronhihttiis', 'broncihttiis', 'bronchhttiis', 'bronchittiis', 'bronchihtiis', 'bronchihtiis', 'bronchihttis', 'bronchihttis', 'bronchihttii']
# input word bronchittiies,
# delete_l = ['ronchittiies', 'bonchittiies', 'brnchittiies', 'brochittiies', 'bronhittiies', 'broncittiies', 'bronchttiies', 'bronchitiies', 'bronchitiies', 'bronchitties', 'bronchitties', 'bronchittiis', 'bronchittiie']
# input word brionchittiis,
# delete_l = ['rionchittiis', 'bionchittiis', 'bronchittiis', 'brinchittiis', 'briochittiis', 'brionhittiis', 'brioncittiis', 'brionchttiis', 'brionchitiis', 'brionchitiis', 'brionchittis', 'brionchittis', 'brionchittii']
# input word bronchititis,
# delete_l = ['ronchititis', 'bonchititis', 'brnchititis', 'brochititis', 'bronhititis', 'broncititis', 'bronchtitis', 'bronchiitis', 'bronchittis', 'bronchitiis', 'bronchitits', 'bronchititi']
# input word bronchittivis,
# delete_l = ['ronchittivis', 'bonchittivis', 'brnchittivis', 'brochittivis', 'bronhittivis', 'broncittivis', 'bronchttivis', 'bronchitivis', 'bronchitivis', 'bronchittvis', 'bronchittiis', 'bronchittivs', 'bronchittivi']
# input word brsnchittiis,
# delete_l = ['rsnchittiis', 'bsnchittiis', 'brnchittiis', 'brschittiis', 'brsnhittiis', 'brsncittiis', 'brsnchttiis', 'brsnchitiis', 'brsnchitiis', 'brsnchittis', 'brsnchittis', 'brsnchittii']
# input word jronchittiis,
# delete_l = ['ronchittiis', 'jonchittiis', 'jrnchittiis', 'jrochittiis', 'jronhittiis', 'jroncittiis', 'jronchttiis', 'jronchitiis', 'jronchitiis', 'jronchittis', 'jronchittis', 'jronchittii']
# input word broncdittiis,
# delete_l = ['roncdittiis', 'boncdittiis', 'brncdittiis', 'brocdittiis', 'brondittiis', 'broncittiis', 'broncdttiis', 'broncditiis', 'broncditiis', 'broncdittis', 'broncdittis', 'broncdittii']
# input word bronchittiif,
# delete_l = ['ronchittiif', 'bonchittiif', 'brnchittiif', 'brochittiif', 'bronhittiif', 'broncittiif', 'bronchttiif', 'bronchitiif', 'bronchitiif', 'bronchittif', 'bronchittif', 'bronchittii']
# input word brondhittiis,
# delete_l = ['rondhittiis', 'bondhittiis', 'brndhittiis', 'brodhittiis', 'bronhittiis', 'brondittiis', 'brondhttiis', 'brondhitiis', 'brondhitiis', 'brondhittis', 'brondhittis', 'brondhittii']
# input word sronchittiis,
# delete_l = ['ronchittiis', 'sonchittiis', 'srnchittiis', 'srochittiis', 'sronhittiis', 'sroncittiis', 'sronchttiis', 'sronchitiis', 'sronchitiis', 'sronchittis', 'sronchittis', 'sronchittii']
# input word brokchittiis,
# delete_l = ['rokchittiis', 'bokchittiis', 'brkchittiis', 'brochittiis', 'brokhittiis', 'brokcittiis', 'brokchttiis', 'brokchitiis', 'brokchitiis', 'brokchittis', 'brokchittis', 'brokchittii']
# input word bronclhittiis,
# delete_l = ['ronclhittiis', 'bonclhittiis', 'brnclhittiis', 'broclhittiis', 'bronlhittiis', 'bronchittiis', 'bronclittiis', 'bronclhttiis', 'bronclhitiis', 'bronclhitiis', 'bronclhittis', 'bronclhittis', 'bronclhittii']
# input word bronchxttiis,
# delete_l = ['ronchxttiis', 'bonchxttiis', 'brnchxttiis', 'brochxttiis', 'bronhxttiis', 'broncxttiis', 'bronchttiis', 'bronchxtiis', 'bronchxtiis', 'bronchxttis', 'bronchxttis', 'bronchxttii']
# input word bronchiattiis,
# delete_l = ['ronchiattiis', 'bonchiattiis', 'brnchiattiis', 'brochiattiis', 'bronhiattiis', 'bronciattiis', 'bronchattiis', 'bronchittiis', 'bronchiatiis', 'bronchiatiis', 'bronchiattis', 'bronchiattis', 'bronchiattii']
# input word broichittiis,
# delete_l = ['roichittiis', 'boichittiis', 'brichittiis', 'brochittiis', 'broihittiis', 'broicittiis', 'broichttiis', 'broichitiis', 'broichitiis', 'broichittis', 'broichittis', 'broichittii']
# input word bronchittiirs,
# delete_l = ['ronchittiirs', 'bonchittiirs', 'brnchittiirs', 'brochittiirs', 'bronhittiirs', 'broncittiirs', 'bronchttiirs', 'bronchitiirs', 'bronchitiirs', 'bronchittirs', 'bronchittirs', 'bronchittiis', 'bronchittiir']
# input word broychittiis,
# delete_l = ['roychittiis', 'boychittiis', 'brychittiis', 'brochittiis', 'broyhittiis', 'broycittiis', 'broychttiis', 'broychitiis', 'broychitiis', 'broychittis', 'broychittis', 'broychittii']
# input word brounchittiis,
# delete_l = ['rounchittiis', 'bounchittiis', 'brunchittiis', 'bronchittiis', 'brouchittiis', 'brounhittiis', 'brouncittiis', 'brounchttiis', 'brounchitiis', 'brounchitiis', 'brounchittis', 'brounchittis', 'brounchittii']
# input word broncmittiis,
# delete_l = ['roncmittiis', 'boncmittiis', 'brncmittiis', 'brocmittiis', 'bronmittiis', 'broncittiis', 'broncmttiis', 'broncmitiis', 'broncmitiis', 'broncmittis', 'broncmittis', 'broncmittii']
# input word bronihittiis,
# delete_l = ['ronihittiis', 'bonihittiis', 'brnihittiis', 'broihittiis', 'bronhittiis', 'broniittiis', 'bronihttiis', 'bronihitiis', 'bronihitiis', 'bronihittis', 'bronihittis', 'bronihittii']
# input word bronchittziis,
# delete_l = ['ronchittziis', 'bonchittziis', 'brnchittziis', 'brochittziis', 'bronhittziis', 'broncittziis', 'bronchttziis', 'bronchitziis', 'bronchitziis', 'bronchittiis', 'bronchittzis', 'bronchittzis', 'bronchittzii']
# input word bronchittiqs,
# delete_l = ['ronchittiqs', 'bonchittiqs', 'brnchittiqs', 'brochittiqs', 'bronhittiqs', 'broncittiqs', 'bronchttiqs', 'bronchitiqs', 'bronchitiqs', 'bronchittqs', 'bronchittis', 'bronchittiq']
# input word broncvhittiis,
# delete_l = ['roncvhittiis', 'boncvhittiis', 'brncvhittiis', 'brocvhittiis', 'bronvhittiis', 'bronchittiis', 'broncvittiis', 'broncvhttiis', 'broncvhitiis', 'broncvhitiis', 'broncvhittis', 'broncvhittis', 'broncvhittii']
# input word broqnchittiis,
# delete_l = ['roqnchittiis', 'boqnchittiis', 'brqnchittiis', 'bronchittiis', 'broqchittiis', 'broqnhittiis', 'broqncittiis', 'broqnchttiis', 'broqnchitiis', 'broqnchitiis', 'broqnchittis', 'broqnchittis', 'broqnchittii']
# input word bronchittiibs,
# delete_l = ['ronchittiibs', 'bonchittiibs', 'brnchittiibs', 'brochittiibs', 'bronhittiibs', 'broncittiibs', 'bronchttiibs', 'bronchitiibs', 'bronchitiibs', 'bronchittibs', 'bronchittibs', 'bronchittiis', 'bronchittiib']
# input word bronchuittiis,
# delete_l = ['ronchuittiis', 'bonchuittiis', 'brnchuittiis', 'brochuittiis', 'bronhuittiis', 'broncuittiis', 'bronchittiis', 'bronchuttiis', 'bronchuitiis', 'bronchuitiis', 'bronchuittis', 'bronchuittis', 'bronchuittii']
# input word bronchittipis,
# delete_l = ['ronchittipis', 'bonchittipis', 'brnchittipis', 'brochittipis', 'bronhittipis', 'broncittipis', 'bronchttipis', 'bronchitipis', 'bronchitipis', 'bronchittpis', 'bronchittiis', 'bronchittips', 'bronchittipi']
# input word bronjchittiis,
# delete_l = ['ronjchittiis', 'bonjchittiis', 'brnjchittiis', 'brojchittiis', 'bronchittiis', 'bronjhittiis', 'bronjcittiis', 'bronjchttiis', 'bronjchitiis', 'bronjchitiis', 'bronjchittis', 'bronjchittis', 'bronjchittii']
# input word bronchittits,
# delete_l = ['ronchittits', 'bonchittits', 'brnchittits', 'brochittits', 'bronhittits', 'broncittits', 'bronchttits', 'bronchitits', 'bronchitits', 'bronchittts', 'bronchittis', 'bronchittit']
# input word bronchittiws,
# delete_l = ['ronchittiws', 'bonchittiws', 'brnchittiws', 'brochittiws', 'bronhittiws', 'broncittiws', 'bronchttiws', 'bronchitiws', 'bronchitiws', 'bronchittws', 'bronchittis', 'bronchittiw']
# input word bronchittibis,
# delete_l = ['ronchittibis', 'bonchittibis', 'brnchittibis', 'brochittibis', 'bronhittibis', 'broncittibis', 'bronchttibis', 'bronchitibis', 'bronchitibis', 'bronchittbis', 'bronchittiis', 'bronchittibs', 'bronchittibi']
# input word bronchittihis,
# delete_l = ['ronchittihis', 'bonchittihis', 'brnchittihis', 'brochittihis', 'bronhittihis', 'broncittihis', 'bronchttihis', 'bronchitihis', 'bronchitihis', 'bronchitthis', 'bronchittiis', 'bronchittihs', 'bronchittihi']
# input word bronchitgtiis,
# delete_l = ['ronchitgtiis', 'bonchitgtiis', 'brnchitgtiis', 'brochitgtiis', 'bronhitgtiis', 'broncitgtiis', 'bronchtgtiis', 'bronchigtiis', 'bronchittiis', 'bronchitgiis', 'bronchitgtis', 'bronchitgtis', 'bronchitgtii']
# input word bronchittifis,
# delete_l = ['ronchittifis', 'bonchittifis', 'brnchittifis', 'brochittifis', 'bronhittifis', 'broncittifis', 'bronchttifis', 'bronchitifis', 'bronchitifis', 'bronchittfis', 'bronchittiis', 'bronchittifs', 'bronchittifi']
# input word brenchittiis,
# delete_l = ['renchittiis', 'benchittiis', 'brnchittiis', 'brechittiis', 'brenhittiis', 'brencittiis', 'brenchttiis', 'brenchitiis', 'brenchitiis', 'brenchittis', 'brenchittis', 'brenchittii']
# input word bronchittwiis,
# delete_l = ['ronchittwiis', 'bonchittwiis', 'brnchittwiis', 'brochittwiis', 'bronhittwiis', 'broncittwiis', 'bronchttwiis', 'bronchitwiis', 'bronchitwiis', 'bronchittiis', 'bronchittwis', 'bronchittwis', 'bronchittwii']
# input word bronchittiid,
# delete_l = ['ronchittiid', 'bonchittiid', 'brnchittiid', 'brochittiid', 'bronhittiid', 'broncittiid', 'bronchttiid', 'bronchitiid', 'bronchitiid', 'bronchittid', 'bronchittid', 'bronchittii']
# input word bronchitjtiis,
# delete_l = ['ronchitjtiis', 'bonchitjtiis', 'brnchitjtiis', 'brochitjtiis', 'bronhitjtiis', 'broncitjtiis', 'bronchtjtiis', 'bronchijtiis', 'bronchittiis', 'bronchitjiis', 'bronchitjtis', 'bronchitjtis', 'bronchitjtii']
# input word brongchittiis,
# delete_l = ['rongchittiis', 'bongchittiis', 'brngchittiis', 'brogchittiis', 'bronchittiis', 'bronghittiis', 'brongcittiis', 'brongchttiis', 'brongchitiis', 'brongchitiis', 'brongchittis', 'brongchittis', 'brongchittii']
# input word ibronchittiis,
# delete_l = ['bronchittiis', 'ironchittiis', 'ibonchittiis', 'ibrnchittiis', 'ibrochittiis', 'ibronhittiis', 'ibroncittiis', 'ibronchttiis', 'ibronchitiis', 'ibronchitiis', 'ibronchittis', 'ibronchittis', 'ibronchittii']
# input word branchittiis,
# delete_l = ['ranchittiis', 'banchittiis', 'brnchittiis', 'brachittiis', 'branhittiis', 'brancittiis', 'branchttiis', 'branchitiis', 'branchitiis', 'branchittis', 'branchittis', 'branchittii']
# input word broncrittiis,
# delete_l = ['roncrittiis', 'boncrittiis', 'brncrittiis', 'brocrittiis', 'bronrittiis', 'broncittiis', 'broncrttiis', 'broncritiis', 'broncritiis', 'broncrittis', 'broncrittis', 'broncrittii']
# input word broznchittiis,
# delete_l = ['roznchittiis', 'boznchittiis', 'brznchittiis', 'bronchittiis', 'brozchittiis', 'broznhittiis', 'brozncittiis', 'broznchttiis', 'broznchitiis', 'broznchitiis', 'broznchittis', 'broznchittis', 'broznchittii']
# input word bqronchittiis,
# delete_l = ['qronchittiis', 'bronchittiis', 'bqonchittiis', 'bqrnchittiis', 'bqrochittiis', 'bqronhittiis', 'bqroncittiis', 'bqronchttiis', 'bqronchitiis', 'bqronchitiis', 'bqronchittis', 'bqronchittis', 'bqronchittii']
# input word bronchittidis,
# delete_l = ['ronchittidis', 'bonchittidis', 'brnchittidis', 'brochittidis', 'bronhittidis', 'broncittidis', 'bronchttidis', 'bronchitidis', 'bronchitidis', 'bronchittdis', 'bronchittiis', 'bronchittids', 'bronchittidi']
# input word bronchitciis,
# delete_l = ['ronchitciis', 'bonchitciis', 'brnchitciis', 'brochitciis', 'bronhitciis', 'broncitciis', 'bronchtciis', 'bronchiciis', 'bronchitiis', 'bronchitcis', 'bronchitcis', 'bronchitcii']
# input word brovnchittiis,
# delete_l = ['rovnchittiis', 'bovnchittiis', 'brvnchittiis', 'bronchittiis', 'brovchittiis', 'brovnhittiis', 'brovncittiis', 'brovnchttiis', 'brovnchitiis', 'brovnchitiis', 'brovnchittis', 'brovnchittis', 'brovnchittii']
# input word bronckittiis,
# delete_l = ['ronckittiis', 'bonckittiis', 'brnckittiis', 'brockittiis', 'bronkittiis', 'broncittiis', 'bronckttiis', 'bronckitiis', 'bronckitiis', 'bronckittis', 'bronckittis', 'bronckittii']
# input word bronchjttiis,
# delete_l = ['ronchjttiis', 'bonchjttiis', 'brnchjttiis', 'brochjttiis', 'bronhjttiis', 'broncjttiis', 'bronchttiis', 'bronchjtiis', 'bronchjtiis', 'bronchjttis', 'bronchjttis', 'bronchjttii']
# input word bronchitbtiis,
# delete_l = ['ronchitbtiis', 'bonchitbtiis', 'brnchitbtiis', 'brochitbtiis', 'bronhitbtiis', 'broncitbtiis', 'bronchtbtiis', 'bronchibtiis', 'bronchittiis', 'bronchitbiis', 'bronchitbtis', 'bronchitbtis', 'bronchitbtii']
# input word bronchitmiis,
# delete_l = ['ronchitmiis', 'bonchitmiis', 'brnchitmiis', 'brochitmiis', 'bronhitmiis', 'broncitmiis', 'bronchtmiis', 'bronchimiis', 'bronchitiis', 'bronchitmis', 'bronchitmis', 'bronchitmii']
# input word bronchiqttiis,
# delete_l = ['ronchiqttiis', 'bonchiqttiis', 'brnchiqttiis', 'brochiqttiis', 'bronhiqttiis', 'bronciqttiis', 'bronchqttiis', 'bronchittiis', 'bronchiqtiis', 'bronchiqtiis', 'bronchiqttis', 'bronchiqttis', 'bronchiqttii']
# input word bronchitthiis,
# delete_l = ['ronchitthiis', 'bonchitthiis', 'brnchitthiis', 'brochitthiis', 'bronhitthiis', 'broncitthiis', 'bronchtthiis', 'bronchithiis', 'bronchithiis', 'bronchittiis', 'bronchitthis', 'bronchitthis', 'bronchitthii']
# input word wronchittiis,
# delete_l = ['ronchittiis', 'wonchittiis', 'wrnchittiis', 'wrochittiis', 'wronhittiis', 'wroncittiis', 'wronchttiis', 'wronchitiis', 'wronchitiis', 'wronchittis', 'wronchittis', 'wronchittii']
# input word bronchitktiis,
# delete_l = ['ronchitktiis', 'bonchitktiis', 'brnchitktiis', 'brochitktiis', 'bronhitktiis', 'broncitktiis', 'bronchtktiis', 'bronchiktiis', 'bronchittiis', 'bronchitkiis', 'bronchitktis', 'bronchitktis', 'bronchitktii']
# input word buonchittiis,
# delete_l = ['uonchittiis', 'bonchittiis', 'bunchittiis', 'buochittiis', 'buonhittiis', 'buoncittiis', 'buonchttiis', 'buonchitiis', 'buonchitiis', 'buonchittis', 'buonchittis', 'buonchittii']
# input word bronchiutiis,
# delete_l = ['ronchiutiis', 'bonchiutiis', 'brnchiutiis', 'brochiutiis', 'bronhiutiis', 'bronciutiis', 'bronchutiis', 'bronchitiis', 'bronchiuiis', 'bronchiutis', 'bronchiutis', 'bronchiutii']
# input word bronqhittiis,
# delete_l = ['ronqhittiis', 'bonqhittiis', 'brnqhittiis', 'broqhittiis', 'bronhittiis', 'bronqittiis', 'bronqhttiis', 'bronqhitiis', 'bronqhitiis', 'bronqhittis', 'bronqhittis', 'bronqhittii']
# input word fronchittiis,
# delete_l = ['ronchittiis', 'fonchittiis', 'frnchittiis', 'frochittiis', 'fronhittiis', 'froncittiis', 'fronchttiis', 'fronchitiis', 'fronchitiis', 'fronchittis', 'fronchittis', 'fronchittii']
# input word bronchitaiis,
# delete_l = ['ronchitaiis', 'bonchitaiis', 'brnchitaiis', 'brochitaiis', 'bronhitaiis', 'broncitaiis', 'bronchtaiis', 'bronchiaiis', 'bronchitiis', 'bronchitais', 'bronchitais', 'bronchitaii']
# input word obronchittiis,
# delete_l = ['bronchittiis', 'oronchittiis', 'obonchittiis', 'obrnchittiis', 'obrochittiis', 'obronhittiis', 'obroncittiis', 'obronchttiis', 'obronchitiis', 'obronchitiis', 'obronchittis', 'obronchittis', 'obronchittii']
# input word bronchittcis,
# delete_l = ['ronchittcis', 'bonchittcis', 'brnchittcis', 'brochittcis', 'bronhittcis', 'broncittcis', 'bronchttcis', 'bronchitcis', 'bronchitcis', 'bronchittis', 'bronchittcs', 'bronchittci']
# input word broncqhittiis,
# delete_l = ['roncqhittiis', 'boncqhittiis', 'brncqhittiis', 'brocqhittiis', 'bronqhittiis', 'bronchittiis', 'broncqittiis', 'broncqhttiis', 'broncqhitiis', 'broncqhitiis', 'broncqhittis', 'broncqhittis', 'broncqhittii']
# input word bronccittiis,
# delete_l = ['ronccittiis', 'bonccittiis', 'brnccittiis', 'broccittiis', 'broncittiis', 'broncittiis', 'bronccttiis', 'bronccitiis', 'bronccitiis', 'bronccittis', 'bronccittis', 'bronccittii']
# input word bronchittpiis,
# delete_l = ['ronchittpiis', 'bonchittpiis', 'brnchittpiis', 'brochittpiis', 'bronhittpiis', 'broncittpiis', 'bronchttpiis', 'bronchitpiis', 'bronchitpiis', 'bronchittiis', 'bronchittpis', 'bronchittpis', 'bronchittpii']
# input word bronchittifs,
# delete_l = ['ronchittifs', 'bonchittifs', 'brnchittifs', 'brochittifs', 'bronhittifs', 'broncittifs', 'bronchttifs', 'bronchitifs', 'bronchitifs', 'bronchittfs', 'bronchittis', 'bronchittif']
# input word kbronchittiis,
# delete_l = ['bronchittiis', 'kronchittiis', 'kbonchittiis', 'kbrnchittiis', 'kbrochittiis', 'kbronhittiis', 'kbroncittiis', 'kbronchttiis', 'kbronchitiis', 'kbronchitiis', 'kbronchittis', 'kbronchittis', 'kbronchittii']
# input word bhronchittiis,
# delete_l = ['hronchittiis', 'bronchittiis', 'bhonchittiis', 'bhrnchittiis', 'bhrochittiis', 'bhronhittiis', 'bhroncittiis', 'bhronchttiis', 'bhronchitiis', 'bhronchitiis', 'bhronchittis', 'bhronchittis', 'bhronchittii']
# input word bromchittiis,
# delete_l = ['romchittiis', 'bomchittiis', 'brmchittiis', 'brochittiis', 'bromhittiis', 'bromcittiis', 'bromchttiis', 'bromchitiis', 'bromchitiis', 'bromchittis', 'bromchittis', 'bromchittii']
# input word bronchisttiis,
# delete_l = ['ronchisttiis', 'bonchisttiis', 'brnchisttiis', 'brochisttiis', 'bronhisttiis', 'broncisttiis', 'bronchsttiis', 'bronchittiis', 'bronchistiis', 'bronchistiis', 'bronchisttis', 'bronchisttis', 'bronchisttii']
# input word bronechittiis,
# delete_l = ['ronechittiis', 'bonechittiis', 'brnechittiis', 'broechittiis', 'bronchittiis', 'bronehittiis', 'bronecittiis', 'bronechttiis', 'bronechitiis', 'bronechitiis', 'bronechittis', 'bronechittis', 'bronechittii']
# input word bronchivtiis,
# delete_l = ['ronchivtiis', 'bonchivtiis', 'brnchivtiis', 'brochivtiis', 'bronhivtiis', 'broncivtiis', 'bronchvtiis', 'bronchitiis', 'bronchiviis', 'bronchivtis', 'bronchivtis', 'bronchivtii']
# input word bronchcttiis,
# delete_l = ['ronchcttiis', 'bonchcttiis', 'brnchcttiis', 'brochcttiis', 'bronhcttiis', 'bronccttiis', 'bronchttiis', 'bronchctiis', 'bronchctiis', 'bronchcttis', 'bronchcttis', 'bronchcttii']
# input word brotnchittiis,
# delete_l = ['rotnchittiis', 'botnchittiis', 'brtnchittiis', 'bronchittiis', 'brotchittiis', 'brotnhittiis', 'brotncittiis', 'brotnchttiis', 'brotnchitiis', 'brotnchitiis', 'brotnchittis', 'brotnchittis', 'brotnchittii']
# input word bronchittiik,
# delete_l = ['ronchittiik', 'bonchittiik', 'brnchittiik', 'brochittiik', 'bronhittiik', 'broncittiik', 'bronchttiik', 'bronchitiik', 'bronchitiik', 'bronchittik', 'bronchittik', 'bronchittii']
# input word bronchigtiis,
# delete_l = ['ronchigtiis', 'bonchigtiis', 'brnchigtiis', 'brochigtiis', 'bronhigtiis', 'broncigtiis', 'bronchgtiis', 'bronchitiis', 'bronchigiis', 'bronchigtis', 'bronchigtis', 'bronchigtii']
# input word brqnchittiis,
# delete_l = ['rqnchittiis', 'bqnchittiis', 'brnchittiis', 'brqchittiis', 'brqnhittiis', 'brqncittiis', 'brqnchttiis', 'brqnchitiis', 'brqnchitiis', 'brqnchittis', 'brqnchittis', 'brqnchittii']
# input word bronchitniis,
# delete_l = ['ronchitniis', 'bonchitniis', 'brnchitniis', 'brochitniis', 'bronhitniis', 'broncitniis', 'bronchtniis', 'bronchiniis', 'bronchitiis', 'bronchitnis', 'bronchitnis', 'bronchitnii']
# input word bronrhittiis,
# delete_l = ['ronrhittiis', 'bonrhittiis', 'brnrhittiis', 'brorhittiis', 'bronhittiis', 'bronrittiis', 'bronrhttiis', 'bronrhitiis', 'bronrhitiis', 'bronrhittis', 'bronrhittis', 'bronrhittii']
# input word bronpchittiis,
# delete_l = ['ronpchittiis', 'bonpchittiis', 'brnpchittiis', 'bropchittiis', 'bronchittiis', 'bronphittiis', 'bronpcittiis', 'bronpchttiis', 'bronpchitiis', 'bronpchitiis', 'bronpchittis', 'bronpchittis', 'bronpchittii']
# input word bropchittiis,
# delete_l = ['ropchittiis', 'bopchittiis', 'brpchittiis', 'brochittiis', 'brophittiis', 'bropcittiis', 'bropchttiis', 'bropchitiis', 'bropchitiis', 'bropchittis', 'bropchittis', 'bropchittii']
# input word bkonchittiis,
# delete_l = ['konchittiis', 'bonchittiis', 'bknchittiis', 'bkochittiis', 'bkonhittiis', 'bkoncittiis', 'bkonchttiis', 'bkonchitiis', 'bkonchitiis', 'bkonchittis', 'bkonchittis', 'bkonchittii']
# input word brwnchittiis,
# delete_l = ['rwnchittiis', 'bwnchittiis', 'brnchittiis', 'brwchittiis', 'brwnhittiis', 'brwncittiis', 'brwnchttiis', 'brwnchitiis', 'brwnchitiis', 'brwnchittis', 'brwnchittis', 'brwnchittii']
# input word bronkchittiis,
# delete_l = ['ronkchittiis', 'bonkchittiis', 'brnkchittiis', 'brokchittiis', 'bronchittiis', 'bronkhittiis', 'bronkcittiis', 'bronkchttiis', 'bronkchitiis', 'bronkchitiis', 'bronkchittis', 'bronkchittis', 'bronkchittii']
# input word bronchittiisb,
# delete_l = ['ronchittiisb', 'bonchittiisb', 'brnchittiisb', 'brochittiisb', 'bronhittiisb', 'broncittiisb', 'bronchttiisb', 'bronchitiisb', 'bronchitiisb', 'bronchittisb', 'bronchittisb', 'bronchittiib', 'bronchittiis']
# input word bronchittisis,
# delete_l = ['ronchittisis', 'bonchittisis', 'brnchittisis', 'brochittisis', 'bronhittisis', 'broncittisis', 'bronchttisis', 'bronchitisis', 'bronchitisis', 'bronchittsis', 'bronchittiis', 'bronchittiss', 'bronchittisi']
# input word bronnhittiis,
# delete_l = ['ronnhittiis', 'bonnhittiis', 'brnnhittiis', 'bronhittiis', 'bronhittiis', 'bronnittiis', 'bronnhttiis', 'bronnhitiis', 'bronnhitiis', 'bronnhittis', 'bronnhittis', 'bronnhittii']
# input word broncvittiis,
# delete_l = ['roncvittiis', 'boncvittiis', 'brncvittiis', 'brocvittiis', 'bronvittiis', 'broncittiis', 'broncvttiis', 'broncvitiis', 'broncvitiis', 'broncvittis', 'broncvittis', 'broncvittii']
# input word bronuchittiis,
# delete_l = ['ronuchittiis', 'bonuchittiis', 'brnuchittiis', 'brouchittiis', 'bronchittiis', 'bronuhittiis', 'bronucittiis', 'bronuchttiis', 'bronuchitiis', 'bronuchitiis', 'bronuchittis', 'bronuchittis', 'bronuchittii']
# input word bronchittibs,
# delete_l = ['ronchittibs', 'bonchittibs', 'brnchittibs', 'brochittibs', 'bronhittibs', 'broncittibs', 'bronchttibs', 'bronchitibs', 'bronchitibs', 'bronchittbs', 'bronchittis', 'bronchittib']
# input word bronchkittiis,
# delete_l = ['ronchkittiis', 'bonchkittiis', 'brnchkittiis', 'brochkittiis', 'bronhkittiis', 'bronckittiis', 'bronchittiis', 'bronchkttiis', 'bronchkitiis', 'bronchkitiis', 'bronchkittis', 'bronchkittis', 'bronchkittii']
# input word fbronchittiis,
# delete_l = ['bronchittiis', 'fronchittiis', 'fbonchittiis', 'fbrnchittiis', 'fbrochittiis', 'fbronhittiis', 'fbroncittiis', 'fbronchttiis', 'fbronchitiis', 'fbronchitiis', 'fbronchittis', 'fbronchittis', 'fbronchittii']
# input word bpronchittiis,
# delete_l = ['pronchittiis', 'bronchittiis', 'bponchittiis', 'bprnchittiis', 'bprochittiis', 'bpronhittiis', 'bproncittiis', 'bpronchttiis', 'bpronchitiis', 'bpronchitiis', 'bpronchittis', 'bpronchittis', 'bpronchittii']
# input word bronchmttiis,
# delete_l = ['ronchmttiis', 'bonchmttiis', 'brnchmttiis', 'brochmttiis', 'bronhmttiis', 'broncmttiis', 'bronchttiis', 'bronchmtiis', 'bronchmtiis', 'bronchmttis', 'bronchmttis', 'bronchmttii']
# input word bronchimttiis,
# delete_l = ['ronchimttiis', 'bonchimttiis', 'brnchimttiis', 'brochimttiis', 'bronhimttiis', 'broncimttiis', 'bronchmttiis', 'bronchittiis', 'bronchimtiis', 'bronchimtiis', 'bronchimttis', 'bronchimttis', 'bronchimttii']
# input word bryonchittiis,
# delete_l = ['ryonchittiis', 'byonchittiis', 'bronchittiis', 'brynchittiis', 'bryochittiis', 'bryonhittiis', 'bryoncittiis', 'bryonchttiis', 'bryonchitiis', 'bryonchitiis', 'bryonchittis', 'bryonchittis', 'bryonchittii']
# input word bronchittinis,
# delete_l = ['ronchittinis', 'bonchittinis', 'brnchittinis', 'brochittinis', 'bronhittinis', 'broncittinis', 'bronchttinis', 'bronchitinis', 'bronchitinis', 'bronchittnis', 'bronchittiis', 'bronchittins', 'bronchittini']
# input word bronchfttiis,
# delete_l = ['ronchfttiis', 'bonchfttiis', 'brnchfttiis', 'brochfttiis', 'bronhfttiis', 'broncfttiis', 'bronchttiis', 'bronchftiis', 'bronchftiis', 'bronchfttis', 'bronchfttis', 'bronchfttii']
# input word bronchittniis,
# delete_l = ['ronchittniis', 'bonchittniis', 'brnchittniis', 'brochittniis', 'bronhittniis', 'broncittniis', 'bronchttniis', 'bronchitniis', 'bronchitniis', 'bronchittiis', 'bronchittnis', 'bronchittnis', 'bronchittnii']
# input word bronchtittiis,
# delete_l = ['ronchtittiis', 'bonchtittiis', 'brnchtittiis', 'brochtittiis', 'bronhtittiis', 'bronctittiis', 'bronchittiis', 'bronchtttiis', 'bronchtitiis', 'bronchtitiis', 'bronchtittis', 'bronchtittis', 'bronchtittii']
# input word baronchittiis,
# delete_l = ['aronchittiis', 'bronchittiis', 'baonchittiis', 'barnchittiis', 'barochittiis', 'baronhittiis', 'baroncittiis', 'baronchttiis', 'baronchitiis', 'baronchitiis', 'baronchittis', 'baronchittis', 'baronchittii']
# input word broncpittiis,
# delete_l = ['roncpittiis', 'boncpittiis', 'brncpittiis', 'brocpittiis', 'bronpittiis', 'broncittiis', 'broncpttiis', 'broncpitiis', 'broncpitiis', 'broncpittis', 'broncpittis', 'broncpittii']
# input word bronchitntiis,
# delete_l = ['ronchitntiis', 'bonchitntiis', 'brnchitntiis', 'brochitntiis', 'bronhitntiis', 'broncitntiis', 'bronchtntiis', 'bronchintiis', 'bronchittiis', 'bronchitniis', 'bronchitntis', 'bronchitntis', 'bronchitntii']
# input word brnnchittiis,
# delete_l = ['rnnchittiis', 'bnnchittiis', 'brnchittiis', 'brnchittiis', 'brnnhittiis', 'brnncittiis', 'brnnchttiis', 'brnnchitiis', 'brnnchitiis', 'brnnchittis', 'brnnchittis', 'brnnchittii']
# input word bronchittiiss,
# delete_l = ['ronchittiiss', 'bonchittiiss', 'brnchittiiss', 'brochittiiss', 'bronhittiiss', 'broncittiiss', 'bronchttiiss', 'bronchitiiss', 'bronchitiiss', 'bronchittiss', 'bronchittiss', 'bronchittiis', 'bronchittiis']
# input word bronxchittiis,
# delete_l = ['ronxchittiis', 'bonxchittiis', 'brnxchittiis', 'broxchittiis', 'bronchittiis', 'bronxhittiis', 'bronxcittiis', 'bronxchttiis', 'bronxchitiis', 'bronxchitiis', 'bronxchittis', 'bronxchittis', 'bronxchittii']
# input word boonchittiis,
# delete_l = ['oonchittiis', 'bonchittiis', 'bonchittiis', 'boochittiis', 'boonhittiis', 'booncittiis', 'boonchttiis', 'boonchitiis', 'boonchitiis', 'boonchittis', 'boonchittis', 'boonchittii']
# input word bronchitftiis,
# delete_l = ['ronchitftiis', 'bonchitftiis', 'brnchitftiis', 'brochitftiis', 'bronhitftiis', 'broncitftiis', 'bronchtftiis', 'bronchiftiis', 'bronchittiis', 'bronchitfiis', 'bronchitftis', 'bronchitftis', 'bronchitftii']
# input word bronchittiist,
# delete_l = ['ronchittiist', 'bonchittiist', 'brnchittiist', 'brochittiist', 'bronhittiist', 'broncittiist', 'bronchttiist', 'bronchitiist', 'bronchitiist', 'bronchittist', 'bronchittist', 'bronchittiit', 'bronchittiis']
# input word bronehittiis,
# delete_l = ['ronehittiis', 'bonehittiis', 'brnehittiis', 'broehittiis', 'bronhittiis', 'broneittiis', 'bronehttiis', 'bronehitiis', 'bronehitiis', 'bronehittis', 'bronehittis', 'bronehittii']
# input word bronchitstiis,
# delete_l = ['ronchitstiis', 'bonchitstiis', 'brnchitstiis', 'brochitstiis', 'bronhitstiis', 'broncitstiis', 'bronchtstiis', 'bronchistiis', 'bronchittiis', 'bronchitsiis', 'bronchitstis', 'bronchitstis', 'bronchitstii']
# input word bronchittigis,
# delete_l = ['ronchittigis', 'bonchittigis', 'brnchittigis', 'brochittigis', 'bronhittigis', 'broncittigis', 'bronchttigis', 'bronchitigis', 'bronchitigis', 'bronchittgis', 'bronchittiis', 'bronchittigs', 'bronchittigi']
# input word bronchlttiis,
# delete_l = ['ronchlttiis', 'bonchlttiis', 'brnchlttiis', 'brochlttiis', 'bronhlttiis', 'bronclttiis', 'bronchttiis', 'bronchltiis', 'bronchltiis', 'bronchlttis', 'bronchlttis', 'bronchlttii']
# input word brfonchittiis,
# delete_l = ['rfonchittiis', 'bfonchittiis', 'bronchittiis', 'brfnchittiis', 'brfochittiis', 'brfonhittiis', 'brfoncittiis', 'brfonchttiis', 'brfonchitiis', 'brfonchitiis', 'brfonchittis', 'brfonchittis', 'brfonchittii']
# input word bronychittiis,
# delete_l = ['ronychittiis', 'bonychittiis', 'brnychittiis', 'broychittiis', 'bronchittiis', 'bronyhittiis', 'bronycittiis', 'bronychttiis', 'bronychitiis', 'bronychitiis', 'bronychittis', 'bronychittis', 'bronychittii']
# input word mbronchittiis,
# delete_l = ['bronchittiis', 'mronchittiis', 'mbonchittiis', 'mbrnchittiis', 'mbrochittiis', 'mbronhittiis', 'mbroncittiis', 'mbronchttiis', 'mbronchitiis', 'mbronchitiis', 'mbronchittis', 'mbronchittis', 'mbronchittii']
# input word broochittiis,
# delete_l = ['roochittiis', 'boochittiis', 'brochittiis', 'brochittiis', 'broohittiis', 'broocittiis', 'broochttiis', 'broochitiis', 'broochitiis', 'broochittis', 'broochittis', 'broochittii']
# input word bronchizttiis,
# delete_l = ['ronchizttiis', 'bonchizttiis', 'brnchizttiis', 'brochizttiis', 'bronhizttiis', 'broncizttiis', 'bronchzttiis', 'bronchittiis', 'bronchiztiis', 'bronchiztiis', 'bronchizttis', 'bronchizttis', 'bronchizttii']
# input word browchittiis,
# delete_l = ['rowchittiis', 'bowchittiis', 'brwchittiis', 'brochittiis', 'browhittiis', 'browcittiis', 'browchttiis', 'browchitiis', 'browchitiis', 'browchittis', 'browchittis', 'browchittii']
# input word bronchittips,
# delete_l = ['ronchittips', 'bonchittips', 'brnchittips', 'brochittips', 'bronhittips', 'broncittips', 'bronchttips', 'bronchitips', 'bronchitips', 'bronchittps', 'bronchittis', 'bronchittip']
# input word bronxhittiis,
# delete_l = ['ronxhittiis', 'bonxhittiis', 'brnxhittiis', 'broxhittiis', 'bronhittiis', 'bronxittiis', 'bronxhttiis', 'bronxhitiis', 'bronxhitiis', 'bronxhittis', 'bronxhittis', 'bronxhittii']
# input word bronchituiis,
# delete_l = ['ronchituiis', 'bonchituiis', 'brnchituiis', 'brochituiis', 'bronhituiis', 'broncituiis', 'bronchtuiis', 'bronchiuiis', 'bronchitiis', 'bronchituis', 'bronchituis', 'bronchituii']
# input word bronchittizis,
# ...
# input word coiid-19,
# delete_l = ['oiid-19', 'ciid-19', 'coid-19', 'coid-19', 'coii-19', 'coiid19', 'coiid-9', 'coiid-1']
# input word covid-1u9,
# delete_l = ['ovid-1u9', 'cvid-1u9', 'coid-1u9', 'covd-1u9', 'covi-1u9', 'covid1u9', 'covid-u9', 'covid-19', 'covid-1u']
# input word covi-d19,
# delete_l = ['ovi-d19', 'cvi-d19', 'coi-d19', 'cov-d19', 'covid19', 'covi-19', 'covi-d9', 'covi-d1']
# input word covid-1i9,
# delete_l = ['ovid-1i9', 'cvid-1i9', 'coid-1i9', 'covd-1i9', 'covi-1i9', 'covid1i9', 'covid-i9', 'covid-19', 'covid-1i']
# input word ucovid-19,
# delete_l = ['covid-19', 'uovid-19', 'ucvid-19', 'ucoid-19', 'ucovd-19', 'ucovi-19', 'ucovid19', 'ucovid-9', 'ucovid-1']
# input word covhid-19,
# delete_l = ['ovhid-19', 'cvhid-19', 'cohid-19', 'covid-19', 'covhd-19', 'covhi-19', 'covhid19', 'covhid-9', 'covhid-1']
# input word covidx-19,
# delete_l = ['ovidx-19', 'cvidx-19', 'coidx-19', 'covdx-19', 'covix-19', 'covid-19', 'covidx19', 'covidx-9', 'covidx-1']
# input word zcovid-19,
# delete_l = ['covid-19', 'zovid-19', 'zcvid-19', 'zcoid-19', 'zcovd-19', 'zcovi-19', 'zcovid19', 'zcovid-9', 'zcovid-1']
# input word fcovid-19,
# delete_l = ['covid-19', 'fovid-19', 'fcvid-19', 'fcoid-19', 'fcovd-19', 'fcovi-19', 'fcovid19', 'fcovid-9', 'fcovid-1']
# input word coxvid-19,
# delete_l = ['oxvid-19', 'cxvid-19', 'covid-19', 'coxid-19', 'coxvd-19', 'coxvi-19', 'coxvid19', 'coxvid-9', 'coxvid-1']
# input word coaid-19,
# delete_l = ['oaid-19', 'caid-19', 'coid-19', 'coad-19', 'coai-19', 'coaid19', 'coaid-9', 'coaid-1']
# input word covid-g9,
# delete_l = ['ovid-g9', 'cvid-g9', 'coid-g9', 'covd-g9', 'covi-g9', 'covidg9', 'covid-9', 'covid-g']
# input word covid-1e,
# delete_l = ['ovid-1e', 'cvid-1e', 'coid-1e', 'covd-1e', 'covi-1e', 'covid1e', 'covid-e', 'covid-1']
# input word covid-1w,
# delete_l = ['ovid-1w', 'cvid-1w', 'coid-1w', 'covd-1w', 'covi-1w', 'covid1w', 'covid-w', 'covid-1']
# input word csovid-19,
# delete_l = ['sovid-19', 'covid-19', 'csvid-19', 'csoid-19', 'csovd-19', 'csovi-19', 'csovid19', 'csovid-9', 'csovid-1']
# input word covida-19,
# delete_l = ['ovida-19', 'cvida-19', 'coida-19', 'covda-19', 'covia-19', 'covid-19', 'covida19', 'covida-9', 'covida-1']
# input word covyd-19,
# delete_l = ['ovyd-19', 'cvyd-19', 'coyd-19', 'covd-19', 'covy-19', 'covyd19', 'covyd-9', 'covyd-1']
# input word covit-19,
# delete_l = ['ovit-19', 'cvit-19', 'coit-19', 'covt-19', 'covi-19', 'covit19', 'covit-9', 'covit-1']
# input word cvoid-19,
# delete_l = ['void-19', 'coid-19', 'cvid-19', 'cvod-19', 'cvoi-19', 'cvoid19', 'cvoid-9', 'cvoid-1']
# input word ycovid-19,
# delete_l = ['covid-19', 'yovid-19', 'ycvid-19', 'ycoid-19', 'ycovd-19', 'ycovi-19', 'ycovid19', 'ycovid-9', 'ycovid-1']
# input word covpid-19,
# delete_l = ['ovpid-19', 'cvpid-19', 'copid-19', 'covid-19', 'covpd-19', 'covpi-19', 'covpid19', 'covpid-9', 'covpid-1']
# input word covik-19,
# delete_l = ['ovik-19', 'cvik-19', 'coik-19', 'covk-19', 'covi-19', 'covik19', 'covik-9', 'covik-1']
# input word coviud-19,
# delete_l = ['oviud-19', 'cviud-19', 'coiud-19', 'covud-19', 'covid-19', 'coviu-19', 'coviud19', 'coviud-9', 'coviud-1']
# input word covid-91,
# delete_l = ['ovid-91', 'cvid-91', 'coid-91', 'covd-91', 'covi-91', 'covid91', 'covid-1', 'covid-9']
# input word covid-p19,
# delete_l = ['ovid-p19', 'cvid-p19', 'coid-p19', 'covd-p19', 'covi-p19', 'covidp19', 'covid-19', 'covid-p9', 'covid-p1']
# input word coviid-19,
# delete_l = ['oviid-19', 'cviid-19', 'coiid-19', 'covid-19', 'covid-19', 'covii-19', 'coviid19', 'coviid-9', 'coviid-1']
# input word covid-z9,
# delete_l = ['ovid-z9', 'cvid-z9', 'coid-z9', 'covd-z9', 'covi-z9', 'covidz9', 'covid-9', 'covid-z']
# input word covid-1h9,
# delete_l = ['ovid-1h9', 'cvid-1h9', 'coid-1h9', 'covd-1h9', 'covi-1h9', 'covid1h9', 'covid-h9', 'covid-19', 'covid-1h']
# input word covicd-19,
# delete_l = ['ovicd-19', 'cvicd-19', 'coicd-19', 'covcd-19', 'covid-19', 'covic-19', 'covicd19', 'covicd-9', 'covicd-1']
# input word cfvid-19,
# delete_l = ['fvid-19', 'cvid-19', 'cfid-19', 'cfvd-19', 'cfvi-19', 'cfvid19', 'cfvid-9', 'cfvid-1']
# input word covid-19e,
# delete_l = ['ovid-19e', 'cvid-19e', 'coid-19e', 'covd-19e', 'covi-19e', 'covid19e', 'covid-9e', 'covid-1e', 'covid-19']
# input word covid-19v,
# delete_l = ['ovid-19v', 'cvid-19v', 'coid-19v', 'covd-19v', 'covi-19v', 'covid19v', 'covid-9v', 'covid-1v', 'covid-19']
# input word cotid-19,
# delete_l = ['otid-19', 'ctid-19', 'coid-19', 'cotd-19', 'coti-19', 'cotid19', 'cotid-9', 'cotid-1']
# input word covsid-19,
# delete_l = ['ovsid-19', 'cvsid-19', 'cosid-19', 'covid-19', 'covsd-19', 'covsi-19', 'covsid19', 'covsid-9', 'covsid-1']
# input word covod-19,
# delete_l = ['ovod-19', 'cvod-19', 'cood-19', 'covd-19', 'covo-19', 'covod19', 'covod-9', 'covod-1']
# input word lovid-19,
# delete_l = ['ovid-19', 'lvid-19', 'loid-19', 'lovd-19', 'lovi-19', 'lovid19', 'lovid-9', 'lovid-1']
# input word covid-1a9,
# delete_l = ['ovid-1a9', 'cvid-1a9', 'coid-1a9', 'covd-1a9', 'covi-1a9', 'covid1a9', 'covid-a9', 'covid-19', 'covid-1a']
# input word colvid-19,
# delete_l = ['olvid-19', 'clvid-19', 'covid-19', 'colid-19', 'colvd-19', 'colvi-19', 'colvid19', 'colvid-9', 'colvid-1']
# input word jovid-19,
# delete_l = ['ovid-19', 'jvid-19', 'joid-19', 'jovd-19', 'jovi-19', 'jovid19', 'jovid-9', 'jovid-1']
# input word rovid-19,
# delete_l = ['ovid-19', 'rvid-19', 'roid-19', 'rovd-19', 'rovi-19', 'rovid19', 'rovid-9', 'rovid-1']
# input word covidl-19,
# delete_l = ['ovidl-19', 'cvidl-19', 'coidl-19', 'covdl-19', 'covil-19', 'covid-19', 'covidl19', 'covidl-9', 'covidl-1']
# input word covid-19r,
# delete_l = ['ovid-19r', 'cvid-19r', 'coid-19r', 'covd-19r', 'covi-19r', 'covid19r', 'covid-9r', 'covid-1r', 'covid-19']
# input word vovid-19,
# delete_l = ['ovid-19', 'vvid-19', 'void-19', 'vovd-19', 'vovi-19', 'vovid19', 'vovid-9', 'vovid-1']
# input word covid-m9,
# delete_l = ['ovid-m9', 'cvid-m9', 'coid-m9', 'covd-m9', 'covi-m9', 'covidm9', 'covid-9', 'covid-m']
# input word hcovid-19,
# delete_l = ['covid-19', 'hovid-19', 'hcvid-19', 'hcoid-19', 'hcovd-19', 'hcovi-19', 'hcovid19', 'hcovid-9', 'hcovid-1']
# input word povid-19,
# delete_l = ['ovid-19', 'pvid-19', 'poid-19', 'povd-19', 'povi-19', 'povid19', 'povid-9', 'povid-1']
# input word covir-19,
# delete_l = ['ovir-19', 'cvir-19', 'coir-19', 'covr-19', 'covi-19', 'covir19', 'covir-9', 'covir-1']
# input word covidk-19,
# delete_l = ['ovidk-19', 'cvidk-19', 'coidk-19', 'covdk-19', 'covik-19', 'covid-19', 'covidk19', 'covidk-9', 'covidk-1']
# input word covied-19,
# delete_l = ['ovied-19', 'cvied-19', 'coied-19', 'coved-19', 'covid-19', 'covie-19', 'covied19', 'covied-9', 'covied-1']
# input word covid-1s,
# delete_l = ['ovid-1s', 'cvid-1s', 'coid-1s', 'covd-1s', 'covi-1s', 'covid1s', 'covid-s', 'covid-1']
# input word pcovid-19,
# delete_l = ['covid-19', 'povid-19', 'pcvid-19', 'pcoid-19', 'pcovd-19', 'pcovi-19', 'pcovid19', 'pcovid-9', 'pcovid-1']
# input word covij-19,
# delete_l = ['ovij-19', 'cvij-19', 'coij-19', 'covj-19', 'covi-19', 'covij19', 'covij-9', 'covij-1']
# input word cwvid-19,
# delete_l = ['wvid-19', 'cvid-19', 'cwid-19', 'cwvd-19', 'cwvi-19', 'cwvid19', 'cwvid-9', 'cwvid-1']
# input word cuvid-19,
# delete_l = ['uvid-19', 'cvid-19', 'cuid-19', 'cuvd-19', 'cuvi-19', 'cuvid19', 'cuvid-9', 'cuvid-1']
# input word covid-19k,
# delete_l = ['ovid-19k', 'cvid-19k', 'coid-19k', 'covd-19k', 'covi-19k', 'covid19k', 'covid-9k', 'covid-1k', 'covid-19']
# input word colid-19,
# delete_l = ['olid-19', 'clid-19', 'coid-19', 'cold-19', 'coli-19', 'colid19', 'colid-9', 'colid-1']
# input word coviy-19,
# delete_l = ['oviy-19', 'cviy-19', 'coiy-19', 'covy-19', 'covi-19', 'coviy19', 'coviy-9', 'coviy-1']
# input word covid-1t9,
# delete_l = ['ovid-1t9', 'cvid-1t9', 'coid-1t9', 'covd-1t9', 'covi-1t9', 'covid1t9', 'covid-t9', 'covid-19', 'covid-1t']
# input word covid-j9,
# delete_l = ['ovid-j9', 'cvid-j9', 'coid-j9', 'covd-j9', 'covi-j9', 'covidj9', 'covid-9', 'covid-j']
# input word cokid-19,
# delete_l = ['okid-19', 'ckid-19', 'coid-19', 'cokd-19', 'coki-19', 'cokid19', 'cokid-9', 'cokid-1']
# input word covid-1a,
# delete_l = ['ovid-1a', 'cvid-1a', 'coid-1a', 'covd-1a', 'covi-1a', 'covid1a', 'covid-a', 'covid-1']
# input word novid-19,
# delete_l = ['ovid-19', 'nvid-19', 'noid-19', 'novd-19', 'novi-19', 'novid19', 'novid-9', 'novid-1']
# input word covid-19z,
# delete_l = ['ovid-19z', 'cvid-19z', 'coid-19z', 'covd-19z', 'covi-19z', 'covid19z', 'covid-9z', 'covid-1z', 'covid-19']
# input word coivd-19,
# delete_l = ['oivd-19', 'civd-19', 'covd-19', 'coid-19', 'coiv-19', 'coivd19', 'coivd-9', 'coivd-1']
# input word covid-v19,
# delete_l = ['ovid-v19', 'cvid-v19', 'coid-v19', 'covd-v19', 'covi-v19', 'covidv19', 'covid-19', 'covid-v9', 'covid-v1']
# input word covif-19,
# delete_l = ['ovif-19', 'cvif-19', 'coif-19', 'covf-19', 'covi-19', 'covif19', 'covif-9', 'covif-1']
# []
# input word live,
# delete_l = ['ive', 'lve', 'lie', 'liv']
# [('give', 0.0026605920147058175), ('live', 0.001354483207486598), ('life', 0.0005365160756927434)]
# input word lost,
# delete_l = ['ost', 'lst', 'lot', 'los']
# [('last', 0.0005305823645168007), ('most', 0.00012760841678252166), ('loss', 6.716232462237983e-05)]
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word i,
# delete_l = ['']
# input word am,
# delete_l = ['m', 'a']
# input word afraid,
# delete_l = ['fraid', 'araid', 'afaid', 'afrid', 'afrad', 'afrai']
# input word that,
# delete_l = ['hat', 'tat', 'tht', 'tha']
# input word she,
# delete_l = ['he', 'se', 'sh']
# input word only,
# delete_l = ['nly', 'oly', 'ony', 'onl']
# input word has,
# delete_l = ['as', 'hs', 'ha']
# input word few,
# delete_l = ['ew', 'fw', 'fe']
# input word more,
# delete_l = ['ore', 'mre', 'moe', 'mor']
# input word months,
# delete_l = ['onths', 'mnths', 'moths', 'monhs', 'monts', 'month']
# input word to,
# delete_l = ['o', 't']
# input word live,
# delete_l = ['ive', 'lve', 'lie', 'liv']
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word system,
# delete_l = ['ystem', 'sstem', 'sytem', 'sysem', 'systm', 'syste']
# input word failure,
# delete_l = ['ailure', 'filure', 'falure', 'faiure', 'failre', 'failue', 'failur']
# input word you,
# delete_l = ['ou', 'yu', 'yo']
# input word should,
# delete_l = ['hould', 'sould', 'shuld', 'shold', 'shoud', 'shoul']
# input word be,
# delete_l = ['e', 'b']
# input word mentally,
# delete_l = ['entally', 'mntally', 'metally', 'menally', 'mentlly', 'mentaly', 'mentaly', 'mentall']
# input word prepared,
# delete_l = ['repared', 'pepared', 'prpared', 'preared', 'prepred', 'prepaed', 'prepard', 'prepare']
# input word she,
# delete_l = ['he', 'se', 'sh']
# input word will,
# delete_l = ['ill', 'wll', 'wil', 'wil']
# input word be,
# delete_l = ['e', 'b']
# input word unconscious,
# delete_l = ['nconscious', 'uconscious', 'unonscious', 'uncnscious', 'uncoscious', 'unconcious', 'unconsious', 'unconscous', 'unconscius', 'unconscios', 'unconsciou']
# input word for,
# delete_l = ['or', 'fr', 'fo']
# input word the,
# delete_l = ['he', 'te', 'th']
# input word next,
# delete_l = ['ext', 'nxt', 'net', 'nex']
# input word few,
# delete_l = ['ew', 'fw', 'fe']
# input word days,
# delete_l = ['ays', 'dys', 'das', 'day']
# input word this,
# delete_l = ['his', 'tis', 'ths', 'thi']
# input word may,
# delete_l = ['ay', 'my', 'ma']
# input word develop,
# delete_l = ['evelop', 'dvelop', 'deelop', 'devlop', 'deveop', 'develp', 'develo']
# input word into,
# delete_l = ['nto', 'ito', 'ino', 'int']
# input word long,
# delete_l = ['ong', 'lng', 'log', 'lon']
# input word cancer,
# delete_l = ['ancer', 'cncer', 'cacer', 'caner', 'cancr', 'cance']
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word the,
# delete_l = ['he', 'te', 'th']
# input word prolonged,
# delete_l = ['rolonged', 'polonged', 'prlonged', 'proonged', 'prolnged', 'prologed', 'proloned', 'prolongd', 'prolonge']
# input word effects,
# delete_l = ['ffects', 'efects', 'efects', 'effcts', 'effets', 'effecs', 'effect']
# input word of,
# delete_l = ['f', 'o']
# input word i,
# delete_l = ['']
# input word am,
# delete_l = ['m', 'a']
# input word sorry,
# delete_l = ['orry', 'srry', 'sory', 'sory', 'sorr']
# input word for,
# delete_l = ['or', 'fr', 'fo']
# input word your,
# delete_l = ['our', 'yur', 'yor', 'you']
# input word lost,
# delete_l = ['ost', 'lst', 'lot', 'los']
# ['due', 'she', 'has', 'live', 'due', 'she', 'due', 'your', 'lost']
# Suitable candidate words are:
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word i,
# delete_l = ['']
# input word am,
# delete_l = ['m', 'a']
# input word afraid,
# delete_l = ['fraid', 'araid', 'afaid', 'afrid', 'afrad', 'afrai']
# input word that,
# delete_l = ['hat', 'tat', 'tht', 'tha']
# input word she,
# delete_l = ['he', 'se', 'sh']
# input word only,
# delete_l = ['nly', 'oly', 'ony', 'onl']
# input word has,
# delete_l = ['as', 'hs', 'ha']
# input word few,
# delete_l = ['ew', 'fw', 'fe']
# input word more,
# delete_l = ['ore', 'mre', 'moe', 'mor']
# input word months,
# delete_l = ['onths', 'mnths', 'moths', 'monhs', 'monts', 'month']
# input word to,
# delete_l = ['o', 't']
# input word live,
# delete_l = ['ive', 'lve', 'lie', 'liv']
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word system,
# delete_l = ['ystem', 'sstem', 'sytem', 'sysem', 'systm', 'syste']
# input word failure,
# delete_l = ['ailure', 'filure', 'falure', 'faiure', 'failre', 'failue', 'failur']
# input word you,
# delete_l = ['ou', 'yu', 'yo']
# input word should,
# delete_l = ['hould', 'sould', 'shuld', 'shold', 'shoud', 'shoul']
# input word be,
# delete_l = ['e', 'b']
# input word mentally,
# delete_l = ['entally', 'mntally', 'metally', 'menally', 'mentlly', 'mentaly', 'mentaly', 'mentall']
# input word prepared,
# delete_l = ['repared', 'pepared', 'prpared', 'preared', 'prepred', 'prepaed', 'prepard', 'prepare']
# input word she,
# delete_l = ['he', 'se', 'sh']
# input word will,
# delete_l = ['ill', 'wll', 'wil', 'wil']
# input word be,
# delete_l = ['e', 'b']
# input word unconscious,
# delete_l = ['nconscious', 'uconscious', 'unonscious', 'uncnscious', 'uncoscious', 'unconcious', 'unconsious', 'unconscous', 'unconscius', 'unconscios', 'unconsciou']
# input word for,
# delete_l = ['or', 'fr', 'fo']
# input word the,
# delete_l = ['he', 'te', 'th']
# input word next,
# delete_l = ['ext', 'nxt', 'net', 'nex']
# input word few,
# delete_l = ['ew', 'fw', 'fe']
# input word days,
# delete_l = ['ays', 'dys', 'das', 'day']
# input word this,
# delete_l = ['his', 'tis', 'ths', 'thi']
# input word may,
# delete_l = ['ay', 'my', 'ma']
# input word develop,
# delete_l = ['evelop', 'dvelop', 'deelop', 'devlop', 'deveop', 'develp', 'develo']
# input word into,
# delete_l = ['nto', 'ito', 'ino', 'int']
# input word long,
# delete_l = ['ong', 'lng', 'log', 'lon']
# input word cancer,
# delete_l = ['ancer', 'cncer', 'cacer', 'caner', 'cancr', 'cance']
# input word due,
# delete_l = ['ue', 'de', 'du']
# input word to,
# delete_l = ['o', 't']
# input word the,
# delete_l = ['he', 'te', 'th']
# input word prolonged,
# delete_l = ['rolonged', 'polonged', 'prlonged', 'proonged', 'prolnged', 'prologed', 'proloned', 'prolongd', 'prolonge']
# input word effects,
# delete_l = ['ffects', 'efects', 'efects', 'effcts', 'effets', 'effecs', 'effect']
# input word of,
# delete_l = ['f', 'o']
# input word i,
# delete_l = ['']
# input word am,
# delete_l = ['m', 'a']
# input word sorry,
# delete_l = ['orry', 'srry', 'sory', 'sory', 'sorr']
# input word for,
# delete_l = ['or', 'fr', 'fo']
# input word your,
# delete_l = ['our', 'yur', 'yor', 'you']
# input word loss,
# delete_l = ['oss', 'lss', 'los', 'los']
# ['due', 'she', 'has', 'live', 'due', 'she', 'due', 'your']
# Suitable candidate words are:
# input word your,
# delete_l = ['our', 'yur', 'yor', 'you']
# [('you', 0.01136289113222313), ('your', 0.003007952712185269), ('our', 0.0009487292711398305)]
# input word your,
# delete_l = ['our', 'yur', 'yor', 'you']
# [('you', 0.01136289113222313), ('your', 0.003007952712185269), ('our', 0.0009487292711398305)]
# input word live,
# delete_l = ['ive', 'lve', 'lie', 'liv']
# [('give', 0.0026605920147058175), ('live', 0.001354483207486598), ('life', 0.0005365160756927434)]
